# %% [markdown]
# # Classification: Ensemble

# %% [markdown]
# ## Data import

# %%
import pandas as pd
df = pd.read_csv('diabetes.csv')

# %%
df
# Out:
#      timespreg  gluctol  diaspb  triceps  insulin  massindex  pedigree  age  \
# 0            6      148      72       35        0       33.6     0.627   50
# 1            1       85      66       29        0       26.6     0.351   31
# 2            8      183      64        0        0       23.3     0.672   32
# 3            1       89      66       23       94       28.1     0.167   21
# 4            0      137      40       35      168       43.1     2.288   33
# ..         ...      ...     ...      ...      ...        ...       ...  ...
# 763         10      101      76       48      180       32.9     0.171   63
# 764          2      122      70       27        0       36.8     0.340   27
# 765          5      121      72       23      112       26.2     0.245   30
# 766          1      126      60        0        0       30.1     0.349   47
# 767          1       93      70       31        0       30.4     0.315   23
#
#      target
# 0         1
# 1         0
# 2         1
# 3         0
# 4         1
# ..      ...
# 763       0
# 764       0
# 765       0
# 766       1
# 767       0
#
# [768 rows x 9 columns]

# %%
#Print class freq. through pandas
print(df.groupby('target').size())

#some imports to plot
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
plt.style.use('ggplot')

#Visualize Class Counts
sns.countplot(y=df.target ,data=df)
plt.xlabel("count of each class")
plt.ylabel("classes")
plt.show()
# Out:
# target
# 0    500
# 1    268
# dtype: int64

# %%
#gives information about the data types,columns, null value counts, memory usage etc
df.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   timespreg  768 non-null    int64
#  1   gluctol    768 non-null    int64
#  2   diaspb     768 non-null    int64
#  3   triceps    768 non-null    int64
#  4   insulin    768 non-null    int64
#  5   massindex  768 non-null    float64
#  6   pedigree   768 non-null    float64
#  7   age        768 non-null    int64
#  8   target     768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %% [markdown]
# ## Data Preparation

# %% [markdown]
# ### Separate Train/Test sets

# %%
#Separate X and y (explanatory variables and target variable)
X = df.iloc[:,0:-1]
y = df.iloc[:,-1] #[-1]]

#X.head()
#y.head()

# %%
from sklearn.model_selection import train_test_split

#SPLIT DATA INTO TRAIN AND TEST SET
X_train, X_test, y_train, y_test = train_test_split(X, y,
                                                    test_size =0.30, #by default is 75%-25%
                                                    #shuffle is set True by default,
                                                    stratify=y, #preserve target propotions
                                                    random_state= 123) #fix random seed for replicability

print(X_train.shape, X_test.shape)
# Out:
# (537, 8) (231, 8)

# %% [markdown]
# # Random Forest

# %% [markdown]
# ![RF](rf.png)

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV

classifier= RandomForestClassifier()
parameters = {'n_estimators' : [50, 100, 200],
    'criterion' : ['entropy', 'gini'],
             'max_depth' : [1,2,3,4],
             'min_samples_split' : [4,5,10],
              'min_samples_leaf' : [4,5,10]
             }

gs = GridSearchCV(classifier, parameters, cv=3, scoring = 'f1', verbose=10, n_jobs=-1, refit=True)

gs.fit(X_train,y_train)
# Out:
# Fitting 3 folds for each of 216 candidates, totalling 648 fits
# [CV 3/3; 1/216] START criterion=entropy, max_depth=1, min_samples_leaf=4, min_samples_split=4, n_estimators=50
# [CV 1/3; 2/216] START criterion=entropy, max_depth=1, min_samples_leaf=4, min_samples_split=4, n_estimators=100
# [CV 3/3; 1/216] END criterion=entropy, max_depth=1, min_samples_leaf=4, min_samples_split=4, n_estimators=50;, score=0.000 total time=   0.1s
# [CV 1/3; 5/216] START criterion=entropy, max_depth=1, min_samples_leaf=4, min_samples_split=5, n_estimators=100
# [CV 1/3; 1/216] START criterion=entropy, max_depth=1, min_samples_leaf=4, min_samples_split=4, n_estimators=50
# [CV 1/3; 2/216] END criterion=entropy, max_depth=1, min_samples_leaf=4, min_samples_split=4, n_estimators=100;, score=0.062 total time=   0.3s
# [CV 1/3; 3/216] START criterion=entropy, max_depth=1, min_samples_leaf=4, min_samples_split=4, n_estimators=200
# [CV 2/3; 5/216] START criterion=entropy, max_depth=1, min_samples_leaf=4, min_samples_split=5, n_estimators=100
# [CV 1/3; 1/216] END criterion=entropy, max_depth=1, min_samples_leaf=4, min_samples_split=4, n_estimators=50;, score=0.222 total time=   0.1s
# [CV 2/3; 2/216] START criterion=entropy, max_depth=1, min_samples_leaf=4, min_samples_split=4, n_estimators=100
# [CV 1/3; 5/216] END criterion=entropy, max_depth=1, min_samples_leaf=4, min_samples_split=5, n_estimators=100;, score=0.062 total time=   0.3s
# [CV 3/3; 5/216] START criterion=entropy, max_depth=1, min_samples_leaf=4, min_samples_split=5, n_estimators=100
# [CV 1/3; 6/216] START criterion=entropy, max_depth=1, min_samples_leaf=4, min_samples_split=5, n_estimators=200
# [CV 2/3; 1/216] START criterion=entropy, max_depth=1, min_samples_leaf=4, min_samples_split=4, n_estimators=50
# [CV 2/3; 4/216] START criterion=entropy, max_depth=1, min_samples_leaf=4, min_samples_split=5, n_estimators=50
# [CV 3/3; 3/216] START criterion=entropy, max_depth=1, min_samples_leaf=4, min_samples_split=4, n_estimators=200
# [CV 3/3; 4/216] START criterion=entropy, max_depth=1, min_samples_leaf=4, min_samples_split=5, n_estimators=50
# [CV 3/3; 2/216] START criterion=entropy, max_depth=1, min_samples_leaf=4, min_samples_split=4, n_estimators=100
# [CV 2/3; 1/216] END criterion=entropy, max_depth=1, min_samples_leaf=4, min_samples_split=4, n_estimators=50;, score=0.370 total time=   0.1s
# [CV 2/3; 4/216] END criterion=entropy, max_depth=1, min_samples_leaf=4, min_samples_split=5, n_estimators=50;, score=0.312 total time=   0.1s
# [CV 2/3; 2/216] END criterion=entropy, max_depth=1, min_samples_leaf=4, min_samples_split=4, n_estimators=100;, score=0.267 total time=   0.2s
# [CV 3/3; 5/216] END criterion=entropy, max_depth=1, min_samples_leaf=4, min_samples_split=5, n_estimators=100;, score=0.370 total time=   0.2s
# [CV 2/3; 5/216] END criterion=entropy, max_depth=1, min_samples_leaf=4, min_samples_split=5, n_estimators=100;, score=0.222 total time=   0.3s
# [CV 2/3; 6/216] START criterion=entropy, max_depth=1, min_samples_leaf=4, min_samples_split=5, n_estimators=200
# [CV 3/3; 6/216] START criterion=entropy, max_depth=1, min_samples_leaf=4, min_samples_split=5, n_estimators=200
# [CV 3/3; 4/216] END criterion=entropy, max_depth=1, min_samples_leaf=4, min_samples_split=5, n_estimators=50;, score=0.118 total time=   0.1s
# [CV 1/3; 7/216] START criterion=entropy, max_depth=1, min_samples_leaf=4, min_samples_split=10, n_estimators=50
# [CV 2/3; 7/216] START criterion=entropy, max_depth=1, min_samples_leaf=4, min_samples_split=10, n_estimators=50
# [CV 3/3; 7/216] START criterion=entropy, max_depth=1, min_samples_leaf=4, min_samples_split=10, n_estimators=50
# [CV 1/3; 8/216] START criterion=entropy, max_depth=1, min_samples_leaf=4, min_samples_split=10, n_estimators=100
# [CV 1/3; 7/216] END criterion=entropy, max_depth=1, min_samples_leaf=4, min_samples_split=10, n_estimators=50;, score=0.118 total time=   0.1s
# [CV 2/3; 8/216] START criterion=entropy, max_depth=1, min_samples_leaf=4, min_samples_split=10, n_estimators=100
# [CV 2/3; 7/216] END criterion=entropy, max_depth=1, min_samples_leaf=4, min_samples_split=10, n_estimators=50;, score=0.354 total time=   0.1s
# [CV 3/3; 7/216] END criterion=entropy, max_depth=1, min_samples_leaf=4, min_samples_split=10, n_estimators=50;, score=0.247 total time=   0.1s
# [CV 3/3; 8/216] START criterion=entropy, max_depth=1, min_samples_leaf=4, min_samples_split=10, n_estimators=100
# [CV 1/3; 9/216] START criterion=entropy, max_depth=1, min_samples_leaf=4, min_samples_split=10, n_estimators=200
# [CV 1/3; 3/216] END criterion=entropy, max_depth=1, min_samples_leaf=4, min_samples_split=4, n_estimators=200;, score=0.062 total time=   0.6s
# [CV 1/3; 6/216] END criterion=entropy, max_depth=1, min_samples_leaf=4, min_samples_split=5, n_estimators=200;, score=0.119 total time=   0.5s
# [CV 2/3; 9/216] START criterion=entropy, max_depth=1, min_samples_leaf=4, min_samples_split=10, n_estimators=200
# [CV 3/3; 2/216] END criterion=entropy, max_depth=1, min_samples_leaf=4, min_samples_split=4, n_estimators=100;, score=0.338 total time=   0.3s
# [CV 3/3; 9/216] START criterion=entropy, max_depth=1, min_samples_leaf=4, min_samples_split=10, n_estimators=200
# [CV 1/3; 4/216] START criterion=entropy, max_depth=1, min_samples_leaf=4, min_samples_split=5, n_estimators=50
# [CV 1/3; 8/216] END criterion=entropy, max_depth=1, min_samples_leaf=4, min_samples_split=10, n_estimators=100;, score=0.031 total time=   0.2s
# [CV 1/3; 10/216] START criterion=entropy, max_depth=1, min_samples_leaf=5, min_samples_split=4, n_estimators=50
# [CV 2/3; 10/216] START criterion=entropy, max_depth=1, min_samples_leaf=5, min_samples_split=4, n_estimators=50
# [CV 3/3; 3/216] END criterion=entropy, max_depth=1, min_samples_leaf=4, min_samples_split=4, n_estimators=200;, score=0.247 total time=   0.5s
# [CV 2/3; 8/216] END criterion=entropy, max_depth=1, min_samples_leaf=4, min_samples_split=10, n_estimators=100;, score=0.429 total time=   0.2s
# [CV 3/3; 10/216] START criterion=entropy, max_depth=1, min_samples_leaf=5, min_samples_split=4, n_estimators=50
# [CV 3/3; 8/216] END criterion=entropy, max_depth=1, min_samples_leaf=4, min_samples_split=10, n_estimators=100;, score=0.118 total time=   0.3s
# [CV 1/3; 11/216] START criterion=entropy, max_depth=1, min_samples_leaf=5, min_samples_split=4, n_estimators=100
# [CV 1/3; 10/216] END criterion=entropy, max_depth=1, min_samples_leaf=5, min_samples_split=4, n_estimators=50;, score=0.062 total time=   0.1s
# [CV 2/3; 11/216] START criterion=entropy, max_depth=1, min_samples_leaf=5, min_samples_split=4, n_estimators=100
# [CV 3/3; 6/216] END criterion=entropy, max_depth=1, min_samples_leaf=4, min_samples_split=5, n_estimators=200;, score=0.286 total time=   0.5s
# [CV 3/3; 11/216] START criterion=entropy, max_depth=1, min_samples_leaf=5, min_samples_split=4, n_estimators=100
# [CV 1/3; 12/216] START criterion=entropy, max_depth=1, min_samples_leaf=5, min_samples_split=4, n_estimators=200
# [CV 2/3; 10/216] END criterion=entropy, max_depth=1, min_samples_leaf=5, min_samples_split=4, n_estimators=50;, score=0.386 total time=   0.1s
# [CV 2/3; 12/216] START criterion=entropy, max_depth=1, min_samples_leaf=5, min_samples_split=4, n_estimators=200
# [CV 2/3; 3/216] START criterion=entropy, max_depth=1, min_samples_leaf=4, min_samples_split=4, n_estimators=200
# [CV 1/3; 4/216] END criterion=entropy, max_depth=1, min_samples_leaf=4, min_samples_split=5, n_estimators=50;, score=0.174 total time=   0.2s
# [CV 3/3; 10/216] END criterion=entropy, max_depth=1, min_samples_leaf=5, min_samples_split=4, n_estimators=50;, score=0.243 total time=   0.1s
# [CV 2/3; 6/216] END criterion=entropy, max_depth=1, min_samples_leaf=4, min_samples_split=5, n_estimators=200;, score=0.293 total time=   0.5s
# [CV 3/3; 12/216] START criterion=entropy, max_depth=1, min_samples_leaf=5, min_samples_split=4, n_estimators=200
# [CV 1/3; 13/216] START criterion=entropy, max_depth=1, min_samples_leaf=5, min_samples_split=5, n_estimators=50
# [CV 2/3; 13/216] START criterion=entropy, max_depth=1, min_samples_leaf=5, min_samples_split=5, n_estimators=50
# [CV 2/3; 9/216] END criterion=entropy, max_depth=1, min_samples_leaf=4, min_samples_split=10, n_estimators=200;, score=0.270 total time=   0.5s
# [CV 3/3; 13/216] START criterion=entropy, max_depth=1, min_samples_leaf=5, min_samples_split=5, n_estimators=50
# [CV 1/3; 11/216] END criterion=entropy, max_depth=1, min_samples_leaf=5, min_samples_split=4, n_estimators=100;, score=0.119 total time=   0.2s
# [CV 1/3; 14/216] START criterion=entropy, max_depth=1, min_samples_leaf=5, min_samples_split=5, n_estimators=100
# [CV 2/3; 11/216] END criterion=entropy, max_depth=1, min_samples_leaf=5, min_samples_split=4, n_estimators=100;, score=0.174 total time=   0.2s
# [CV 2/3; 14/216] START criterion=entropy, max_depth=1, min_samples_leaf=5, min_samples_split=5, n_estimators=100
# [CV 1/3; 13/216] END criterion=entropy, max_depth=1, min_samples_leaf=5, min_samples_split=5, n_estimators=50;, score=0.062 total time=   0.2s
# [CV 3/3; 14/216] START criterion=entropy, max_depth=1, min_samples_leaf=5, min_samples_split=5, n_estimators=100
# [CV 3/3; 11/216] END criterion=entropy, max_depth=1, min_samples_leaf=5, min_samples_split=4, n_estimators=100;, score=0.308 total time=   0.3s
# [CV 1/3; 15/216] START criterion=entropy, max_depth=1, min_samples_leaf=5, min_samples_split=5, n_estimators=200
# [CV 1/3; 9/216] END criterion=entropy, max_depth=1, min_samples_leaf=4, min_samples_split=10, n_estimators=200;, score=0.091 total time=   0.6s
# [CV 2/3; 15/216] START criterion=entropy, max_depth=1, min_samples_leaf=5, min_samples_split=5, n_estimators=200
# [CV 3/3; 9/216] END criterion=entropy, max_depth=1, min_samples_leaf=4, min_samples_split=10, n_estimators=200;, score=0.316 total time=   0.5s
# [CV 3/3; 15/216] START criterion=entropy, max_depth=1, min_samples_leaf=5, min_samples_split=5, n_estimators=200
# [CV 3/3; 13/216] END criterion=entropy, max_depth=1, min_samples_leaf=5, min_samples_split=5, n_estimators=50;, score=0.171 total time=   0.2s
# [CV 1/3; 16/216] START criterion=entropy, max_depth=1, min_samples_leaf=5, min_samples_split=10, n_estimators=50
# [CV 1/3; 14/216] END criterion=entropy, max_depth=1, min_samples_leaf=5, min_samples_split=5, n_estimators=100;, score=0.000 total time=   0.2s
# [CV 2/3; 16/216] START criterion=entropy, max_depth=1, min_samples_leaf=5, min_samples_split=10, n_estimators=50
# [CV 1/3; 12/216] END criterion=entropy, max_depth=1, min_samples_leaf=5, min_samples_split=4, n_estimators=200;, score=0.031 total time=   0.5s
# [CV 3/3; 16/216] START criterion=entropy, max_depth=1, min_samples_leaf=5, min_samples_split=10, n_estimators=50
# [CV 2/3; 14/216] END criterion=entropy, max_depth=1, min_samples_leaf=5, min_samples_split=5, n_estimators=100;, score=0.293 total time=   0.3s
# [CV 1/3; 17/216] START criterion=entropy, max_depth=1, min_samples_leaf=5, min_samples_split=10, n_estimators=100
# [CV 2/3; 12/216] END criterion=entropy, max_depth=1, min_samples_leaf=5, min_samples_split=4, n_estimators=200;, score=0.289 total time=   0.5s
# [CV 2/3; 17/216] START criterion=entropy, max_depth=1, min_samples_leaf=5, min_samples_split=10, n_estimators=100
# [CV 2/3; 13/216] END criterion=entropy, max_depth=1, min_samples_leaf=5, min_samples_split=5, n_estimators=50;, score=0.312 total time=   0.4s
# [CV 3/3; 17/216] START criterion=entropy, max_depth=1, min_samples_leaf=5, min_samples_split=10, n_estimators=100
# [CV 1/3; 16/216] END criterion=entropy, max_depth=1, min_samples_leaf=5, min_samples_split=10, n_estimators=50;, score=0.119 total time=   0.2s
# [CV 1/3; 18/216] START criterion=entropy, max_depth=1, min_samples_leaf=5, min_samples_split=10, n_estimators=200
# [CV 2/3; 16/216] END criterion=entropy, max_depth=1, min_samples_leaf=5, min_samples_split=10, n_estimators=50;, score=0.267 total time=   0.1s
# [CV 2/3; 18/216] START criterion=entropy, max_depth=1, min_samples_leaf=5, min_samples_split=10, n_estimators=200
# [CV 3/3; 16/216] END criterion=entropy, max_depth=1, min_samples_leaf=5, min_samples_split=10, n_estimators=50;, score=0.222 total time=   0.1s
# [CV 3/3; 18/216] START criterion=entropy, max_depth=1, min_samples_leaf=5, min_samples_split=10, n_estimators=200
# [CV 3/3; 12/216] END criterion=entropy, max_depth=1, min_samples_leaf=5, min_samples_split=4, n_estimators=200;, score=0.293 total time=   0.6s
# [CV 1/3; 19/216] START criterion=entropy, max_depth=1, min_samples_leaf=10, min_samples_split=4, n_estimators=50
# [CV 2/3; 3/216] END criterion=entropy, max_depth=1, min_samples_leaf=4, min_samples_split=4, n_estimators=200;, score=0.286 total time=   0.6s
# [CV 3/3; 14/216] END criterion=entropy, max_depth=1, min_samples_leaf=5, min_samples_split=5, n_estimators=100;, score=0.000 total time=   0.4s
# [CV 2/3; 19/216] START criterion=entropy, max_depth=1, min_samples_leaf=10, min_samples_split=4, n_estimators=50
# [CV 3/3; 19/216] START criterion=entropy, max_depth=1, min_samples_leaf=10, min_samples_split=4, n_estimators=50
# [CV 1/3; 17/216] END criterion=entropy, max_depth=1, min_samples_leaf=5, min_samples_split=10, n_estimators=100;, score=0.091 total time=   0.2s
# [CV 1/3; 19/216] END criterion=entropy, max_depth=1, min_samples_leaf=10, min_samples_split=4, n_estimators=50;, score=0.000 total time=   0.1s
# [CV 1/3; 20/216] START criterion=entropy, max_depth=1, min_samples_leaf=10, min_samples_split=4, n_estimators=100[CV 2/3; 20/216] START criterion=entropy, max_depth=1, min_samples_leaf=10, min_samples_split=4, n_estimators=100
#
# [CV 2/3; 17/216] END criterion=entropy, max_depth=1, min_samples_leaf=5, min_samples_split=10, n_estimators=100;, score=0.329 total time=   0.2s
# [CV 3/3; 20/216] START criterion=entropy, max_depth=1, min_samples_leaf=10, min_samples_split=4, n_estimators=100
# [CV 2/3; 19/216] END criterion=entropy, max_depth=1, min_samples_leaf=10, min_samples_split=4, n_estimators=50;, score=0.247 total time=   0.1s
# [CV 1/3; 21/216] START criterion=entropy, max_depth=1, min_samples_leaf=10, min_samples_split=4, n_estimators=200
# [CV 2/3; 15/216] END criterion=entropy, max_depth=1, min_samples_leaf=5, min_samples_split=5, n_estimators=200;, score=0.293 total time=   0.5s
# [CV 2/3; 21/216] START criterion=entropy, max_depth=1, min_samples_leaf=10, min_samples_split=4, n_estimators=200
# [CV 3/3; 15/216] END criterion=entropy, max_depth=1, min_samples_leaf=5, min_samples_split=5, n_estimators=200;, score=0.197 total time=   0.5s
# [CV 3/3; 21/216] START criterion=entropy, max_depth=1, min_samples_leaf=10, min_samples_split=4, n_estimators=200
# [CV 1/3; 15/216] END criterion=entropy, max_depth=1, min_samples_leaf=5, min_samples_split=5, n_estimators=200;, score=0.091 total time=   0.6s
# [CV 1/3; 22/216] START criterion=entropy, max_depth=1, min_samples_leaf=10, min_samples_split=5, n_estimators=50
# [CV 3/3; 19/216] END criterion=entropy, max_depth=1, min_samples_leaf=10, min_samples_split=4, n_estimators=50;, score=0.293 total time=   0.2s
# [CV 2/3; 22/216] START criterion=entropy, max_depth=1, min_samples_leaf=10, min_samples_split=5, n_estimators=50
# [CV 3/3; 17/216] END criterion=entropy, max_depth=1, min_samples_leaf=5, min_samples_split=10, n_estimators=100;, score=0.325 total time=   0.3s
# [CV 3/3; 22/216] START criterion=entropy, max_depth=1, min_samples_leaf=10, min_samples_split=5, n_estimators=50
# [CV 1/3; 22/216] END criterion=entropy, max_depth=1, min_samples_leaf=10, min_samples_split=5, n_estimators=50;, score=0.062 total time=   0.1s
# [CV 1/3; 23/216] START criterion=entropy, max_depth=1, min_samples_leaf=10, min_samples_split=5, n_estimators=100
# [CV 2/3; 22/216] END criterion=entropy, max_depth=1, min_samples_leaf=10, min_samples_split=5, n_estimators=50;, score=0.286 total time=   0.1s
# [CV 2/3; 23/216] START criterion=entropy, max_depth=1, min_samples_leaf=10, min_samples_split=5, n_estimators=100
# [CV 2/3; 20/216] END criterion=entropy, max_depth=1, min_samples_leaf=10, min_samples_split=4, n_estimators=100;, score=0.424 total time=   0.3s
# [CV 3/3; 23/216] START criterion=entropy, max_depth=1, min_samples_leaf=10, min_samples_split=5, n_estimators=100
# [CV 3/3; 22/216] END criterion=entropy, max_depth=1, min_samples_leaf=10, min_samples_split=5, n_estimators=50;, score=0.062 total time=   0.1s
# [CV 1/3; 24/216] START criterion=entropy, max_depth=1, min_samples_leaf=10, min_samples_split=5, n_estimators=200
# [CV 3/3; 20/216] END criterion=entropy, max_depth=1, min_samples_leaf=10, min_samples_split=4, n_estimators=100;, score=0.247 total time=   0.3s
# [CV 2/3; 24/216] START criterion=entropy, max_depth=1, min_samples_leaf=10, min_samples_split=5, n_estimators=200
# [CV 2/3; 18/216] END criterion=entropy, max_depth=1, min_samples_leaf=5, min_samples_split=10, n_estimators=200;, score=0.329 total time=   0.5s
# [CV 3/3; 24/216] START criterion=entropy, max_depth=1, min_samples_leaf=10, min_samples_split=5, n_estimators=200
# [CV 1/3; 18/216] END criterion=entropy, max_depth=1, min_samples_leaf=5, min_samples_split=10, n_estimators=200;, score=0.062 total time=   0.5s
# [CV 1/3; 25/216] START criterion=entropy, max_depth=1, min_samples_leaf=10, min_samples_split=10, n_estimators=50
# [CV 3/3; 18/216] END criterion=entropy, max_depth=1, min_samples_leaf=5, min_samples_split=10, n_estimators=200;, score=0.247 total time=   0.5s
# [CV 2/3; 25/216] START criterion=entropy, max_depth=1, min_samples_leaf=10, min_samples_split=10, n_estimators=50
# [CV 1/3; 20/216] END criterion=entropy, max_depth=1, min_samples_leaf=10, min_samples_split=4, n_estimators=100;, score=0.062 total time=   0.4s
# [CV 3/3; 25/216] START criterion=entropy, max_depth=1, min_samples_leaf=10, min_samples_split=10, n_estimators=50
# [CV 1/3; 23/216] END criterion=entropy, max_depth=1, min_samples_leaf=10, min_samples_split=5, n_estimators=100;, score=0.118 total time=   0.2s
# [CV 1/3; 25/216] END criterion=entropy, max_depth=1, min_samples_leaf=10, min_samples_split=10, n_estimators=50;, score=0.000 total time=   0.1s
# [CV 1/3; 26/216] START criterion=entropy, max_depth=1, min_samples_leaf=10, min_samples_split=10, n_estimators=100
# [CV 2/3; 26/216] START criterion=entropy, max_depth=1, min_samples_leaf=10, min_samples_split=10, n_estimators=100
# [CV 3/3; 23/216] END criterion=entropy, max_depth=1, min_samples_leaf=10, min_samples_split=5, n_estimators=100;, score=0.119 total time=   0.3s
# [CV 2/3; 23/216] END criterion=entropy, max_depth=1, min_samples_leaf=10, min_samples_split=5, n_estimators=100;, score=0.329 total time=   0.3s
# [CV 3/3; 26/216] START criterion=entropy, max_depth=1, min_samples_leaf=10, min_samples_split=10, n_estimators=100[CV 3/3; 21/216] END criterion=entropy, max_depth=1, min_samples_leaf=10, min_samples_split=4, n_estimators=200;, score=0.270 total time=   0.4s
#
# [CV 1/3; 27/216] START criterion=entropy, max_depth=1, min_samples_leaf=10, min_samples_split=10, n_estimators=200
# [CV 2/3; 27/216] START criterion=entropy, max_depth=1, min_samples_leaf=10, min_samples_split=10, n_estimators=200
# [CV 1/3; 21/216] END criterion=entropy, max_depth=1, min_samples_leaf=10, min_samples_split=4, n_estimators=200;, score=0.062 total time=   0.5s
# [CV 2/3; 25/216] END criterion=entropy, max_depth=1, min_samples_leaf=10, min_samples_split=10, n_estimators=50;, score=0.274 total time=   0.1s
# [CV 3/3; 27/216] START criterion=entropy, max_depth=1, min_samples_leaf=10, min_samples_split=10, n_estimators=200
# [CV 1/3; 28/216] START criterion=entropy, max_depth=2, min_samples_leaf=4, min_samples_split=4, n_estimators=50
# [CV 2/3; 21/216] END criterion=entropy, max_depth=1, min_samples_leaf=10, min_samples_split=4, n_estimators=200;, score=0.333 total time=   0.5s
# [CV 2/3; 28/216] START criterion=entropy, max_depth=2, min_samples_leaf=4, min_samples_split=4, n_estimators=50
# [CV 3/3; 25/216] END criterion=entropy, max_depth=1, min_samples_leaf=10, min_samples_split=10, n_estimators=50;, score=0.145 total time=   0.2s
# [CV 3/3; 28/216] START criterion=entropy, max_depth=2, min_samples_leaf=4, min_samples_split=4, n_estimators=50
# [CV 1/3; 28/216] END criterion=entropy, max_depth=2, min_samples_leaf=4, min_samples_split=4, n_estimators=50;, score=0.583 total time=   0.1s
# [CV 1/3; 29/216] START criterion=entropy, max_depth=2, min_samples_leaf=4, min_samples_split=4, n_estimators=100
# [CV 2/3; 28/216] END criterion=entropy, max_depth=2, min_samples_leaf=4, min_samples_split=4, n_estimators=50;, score=0.500 total time=   0.1s
# [CV 2/3; 29/216] START criterion=entropy, max_depth=2, min_samples_leaf=4, min_samples_split=4, n_estimators=100
# [CV 2/3; 26/216] END criterion=entropy, max_depth=1, min_samples_leaf=10, min_samples_split=10, n_estimators=100;, score=0.274 total time=   0.2s
# [CV 1/3; 26/216] END criterion=entropy, max_depth=1, min_samples_leaf=10, min_samples_split=10, n_estimators=100;, score=0.031 total time=   0.3s
# [CV 3/3; 29/216] START criterion=entropy, max_depth=2, min_samples_leaf=4, min_samples_split=4, n_estimators=100[CV 1/3; 30/216] START criterion=entropy, max_depth=2, min_samples_leaf=4, min_samples_split=4, n_estimators=200
#
# [CV 3/3; 28/216] END criterion=entropy, max_depth=2, min_samples_leaf=4, min_samples_split=4, n_estimators=50;, score=0.444 total time=   0.1s
# [CV 2/3; 30/216] START criterion=entropy, max_depth=2, min_samples_leaf=4, min_samples_split=4, n_estimators=200
# [CV 3/3; 26/216] END criterion=entropy, max_depth=1, min_samples_leaf=10, min_samples_split=10, n_estimators=100;, score=0.247 total time=   0.3s
# [CV 3/3; 30/216] START criterion=entropy, max_depth=2, min_samples_leaf=4, min_samples_split=4, n_estimators=200
# [CV 1/3; 24/216] END criterion=entropy, max_depth=1, min_samples_leaf=10, min_samples_split=5, n_estimators=200;, score=0.062 total time=   0.5s
# [CV 1/3; 31/216] START criterion=entropy, max_depth=2, min_samples_leaf=4, min_samples_split=5, n_estimators=50
# [CV 2/3; 24/216] END criterion=entropy, max_depth=1, min_samples_leaf=10, min_samples_split=5, n_estimators=200;, score=0.386 total time=   0.6s
# [CV 2/3; 31/216] START criterion=entropy, max_depth=2, min_samples_leaf=4, min_samples_split=5, n_estimators=50
# [CV 2/3; 29/216] END criterion=entropy, max_depth=2, min_samples_leaf=4, min_samples_split=4, n_estimators=100;, score=0.542 total time=   0.2s
# [CV 1/3; 29/216] END criterion=entropy, max_depth=2, min_samples_leaf=4, min_samples_split=4, n_estimators=100;, score=0.606 total time=   0.3s
# [CV 3/3; 31/216] START criterion=entropy, max_depth=2, min_samples_leaf=4, min_samples_split=5, n_estimators=50
# [CV 1/3; 31/216] END criterion=entropy, max_depth=2, min_samples_leaf=4, min_samples_split=5, n_estimators=50;, score=0.429 total time=   0.1s
# [CV 1/3; 32/216] START criterion=entropy, max_depth=2, min_samples_leaf=4, min_samples_split=5, n_estimators=100
# [CV 2/3; 32/216] START criterion=entropy, max_depth=2, min_samples_leaf=4, min_samples_split=5, n_estimators=100
# [CV 3/3; 29/216] END criterion=entropy, max_depth=2, min_samples_leaf=4, min_samples_split=4, n_estimators=100;, score=0.432 total time=   0.2s
# [CV 3/3; 32/216] START criterion=entropy, max_depth=2, min_samples_leaf=4, min_samples_split=5, n_estimators=100
# [CV 2/3; 27/216] END criterion=entropy, max_depth=1, min_samples_leaf=10, min_samples_split=10, n_estimators=200;, score=0.308 total time=   0.5s
# [CV 1/3; 33/216] START criterion=entropy, max_depth=2, min_samples_leaf=4, min_samples_split=5, n_estimators=200
# [CV 3/3; 31/216] END criterion=entropy, max_depth=2, min_samples_leaf=4, min_samples_split=5, n_estimators=50;, score=0.424 total time=   0.1s
# [CV 2/3; 33/216] START criterion=entropy, max_depth=2, min_samples_leaf=4, min_samples_split=5, n_estimators=200
# [CV 2/3; 31/216] END criterion=entropy, max_depth=2, min_samples_leaf=4, min_samples_split=5, n_estimators=50;, score=0.532 total time=   0.2s
# [CV 3/3; 33/216] START criterion=entropy, max_depth=2, min_samples_leaf=4, min_samples_split=5, n_estimators=200
# [CV 3/3; 24/216] END criterion=entropy, max_depth=1, min_samples_leaf=10, min_samples_split=5, n_estimators=200;, score=0.270 total time=   0.8s
# [CV 1/3; 34/216] START criterion=entropy, max_depth=2, min_samples_leaf=4, min_samples_split=10, n_estimators=50[CV 3/3; 27/216] END criterion=entropy, max_depth=1, min_samples_leaf=10, min_samples_split=10, n_estimators=200;, score=0.222 total time=   0.6s
#
# [CV 2/3; 34/216] START criterion=entropy, max_depth=2, min_samples_leaf=4, min_samples_split=10, n_estimators=50
# [CV 1/3; 27/216] END criterion=entropy, max_depth=1, min_samples_leaf=10, min_samples_split=10, n_estimators=200;, score=0.062 total time=   0.6s
# [CV 3/3; 34/216] START criterion=entropy, max_depth=2, min_samples_leaf=4, min_samples_split=10, n_estimators=50
# [CV 1/3; 30/216] END criterion=entropy, max_depth=2, min_samples_leaf=4, min_samples_split=4, n_estimators=200;, score=0.536 total time=   0.5s
# [CV 1/3; 35/216] START criterion=entropy, max_depth=2, min_samples_leaf=4, min_samples_split=10, n_estimators=100
# [CV 3/3; 32/216] END criterion=entropy, max_depth=2, min_samples_leaf=4, min_samples_split=5, n_estimators=100;, score=0.455 total time=   0.3s[CV 1/3; 32/216] END criterion=entropy, max_depth=2, min_samples_leaf=4, min_samples_split=5, n_estimators=100;, score=0.538 total time=   0.3s
#
# [CV 2/3; 35/216] START criterion=entropy, max_depth=2, min_samples_leaf=4, min_samples_split=10, n_estimators=100
# [CV 3/3; 35/216] START criterion=entropy, max_depth=2, min_samples_leaf=4, min_samples_split=10, n_estimators=100
# [CV 2/3; 32/216] END criterion=entropy, max_depth=2, min_samples_leaf=4, min_samples_split=5, n_estimators=100;, score=0.516 total time=   0.3s
# [CV 1/3; 36/216] START criterion=entropy, max_depth=2, min_samples_leaf=4, min_samples_split=10, n_estimators=200
# [CV 3/3; 30/216] END criterion=entropy, max_depth=2, min_samples_leaf=4, min_samples_split=4, n_estimators=200;, score=0.437 total time=   0.5s
# [CV 2/3; 36/216] START criterion=entropy, max_depth=2, min_samples_leaf=4, min_samples_split=10, n_estimators=200
# [CV 2/3; 30/216] END criterion=entropy, max_depth=2, min_samples_leaf=4, min_samples_split=4, n_estimators=200;, score=0.516 total time=   0.6s
# [CV 3/3; 36/216] START criterion=entropy, max_depth=2, min_samples_leaf=4, min_samples_split=10, n_estimators=200
# [CV 2/3; 34/216] END criterion=entropy, max_depth=2, min_samples_leaf=4, min_samples_split=10, n_estimators=50;, score=0.542 total time=   0.2s
# [CV 1/3; 37/216] START criterion=entropy, max_depth=2, min_samples_leaf=5, min_samples_split=4, n_estimators=50
# [CV 1/3; 34/216] END criterion=entropy, max_depth=2, min_samples_leaf=4, min_samples_split=10, n_estimators=50;, score=0.557 total time=   0.3s
# [CV 2/3; 37/216] START criterion=entropy, max_depth=2, min_samples_leaf=5, min_samples_split=4, n_estimators=50
# [CV 3/3; 34/216] END criterion=entropy, max_depth=2, min_samples_leaf=4, min_samples_split=10, n_estimators=50;, score=0.455 total time=   0.3s
# [CV 3/3; 37/216] START criterion=entropy, max_depth=2, min_samples_leaf=5, min_samples_split=4, n_estimators=50
# [CV 1/3; 35/216] END criterion=entropy, max_depth=2, min_samples_leaf=4, min_samples_split=10, n_estimators=100;, score=0.547 total time=   0.3s
# [CV 1/3; 38/216] START criterion=entropy, max_depth=2, min_samples_leaf=5, min_samples_split=4, n_estimators=100
# [CV 1/3; 33/216] END criterion=entropy, max_depth=2, min_samples_leaf=4, min_samples_split=5, n_estimators=200;, score=0.495 total time=   0.5s
# [CV 2/3; 38/216] START criterion=entropy, max_depth=2, min_samples_leaf=5, min_samples_split=4, n_estimators=100
# [CV 2/3; 35/216] END criterion=entropy, max_depth=2, min_samples_leaf=4, min_samples_split=10, n_estimators=100;, score=0.562 total time=   0.3s
# [CV 1/3; 37/216] END criterion=entropy, max_depth=2, min_samples_leaf=5, min_samples_split=4, n_estimators=50;, score=0.562 total time=   0.2s
# [CV 3/3; 38/216] START criterion=entropy, max_depth=2, min_samples_leaf=5, min_samples_split=4, n_estimators=100[CV 1/3; 39/216] START criterion=entropy, max_depth=2, min_samples_leaf=5, min_samples_split=4, n_estimators=200
#
# [CV 2/3; 37/216] END criterion=entropy, max_depth=2, min_samples_leaf=5, min_samples_split=4, n_estimators=50;, score=0.557 total time=   0.1s
# [CV 2/3; 39/216] START criterion=entropy, max_depth=2, min_samples_leaf=5, min_samples_split=4, n_estimators=200
# [CV 3/3; 35/216] END criterion=entropy, max_depth=2, min_samples_leaf=4, min_samples_split=10, n_estimators=100;, score=0.419 total time=   0.4s
# [CV 2/3; 33/216] END criterion=entropy, max_depth=2, min_samples_leaf=4, min_samples_split=5, n_estimators=200;, score=0.532 total time=   0.5s
# [CV 3/3; 39/216] START criterion=entropy, max_depth=2, min_samples_leaf=5, min_samples_split=4, n_estimators=200
# [CV 1/3; 40/216] START criterion=entropy, max_depth=2, min_samples_leaf=5, min_samples_split=5, n_estimators=50
# [CV 3/3; 37/216] END criterion=entropy, max_depth=2, min_samples_leaf=5, min_samples_split=4, n_estimators=50;, score=0.489 total time=   0.1s
# [CV 2/3; 40/216] START criterion=entropy, max_depth=2, min_samples_leaf=5, min_samples_split=5, n_estimators=50
# [CV 1/3; 38/216] END criterion=entropy, max_depth=2, min_samples_leaf=5, min_samples_split=4, n_estimators=100;, score=0.522 total time=   0.3s
# [CV 3/3; 40/216] START criterion=entropy, max_depth=2, min_samples_leaf=5, min_samples_split=5, n_estimators=50
# [CV 2/3; 40/216] END criterion=entropy, max_depth=2, min_samples_leaf=5, min_samples_split=5, n_estimators=50;, score=0.505 total time=   0.2s
# [CV 1/3; 41/216] START criterion=entropy, max_depth=2, min_samples_leaf=5, min_samples_split=5, n_estimators=100
# [CV 3/3; 38/216] END criterion=entropy, max_depth=2, min_samples_leaf=5, min_samples_split=4, n_estimators=100;, score=0.449 total time=   0.3s[CV 2/3; 38/216] END criterion=entropy, max_depth=2, min_samples_leaf=5, min_samples_split=4, n_estimators=100;, score=0.542 total time=   0.3s
#
# [CV 2/3; 41/216] START criterion=entropy, max_depth=2, min_samples_leaf=5, min_samples_split=5, n_estimators=100[CV 3/3; 41/216] START criterion=entropy, max_depth=2, min_samples_leaf=5, min_samples_split=5, n_estimators=100
#
# [CV 3/3; 36/216] END criterion=entropy, max_depth=2, min_samples_leaf=4, min_samples_split=10, n_estimators=200;, score=0.442 total time=   0.5s
# [CV 1/3; 42/216] START criterion=entropy, max_depth=2, min_samples_leaf=5, min_samples_split=5, n_estimators=200
# [CV 1/3; 40/216] END criterion=entropy, max_depth=2, min_samples_leaf=5, min_samples_split=5, n_estimators=50;, score=0.592 total time=   0.2s
# [CV 2/3; 42/216] START criterion=entropy, max_depth=2, min_samples_leaf=5, min_samples_split=5, n_estimators=200
# [CV 1/3; 36/216] END criterion=entropy, max_depth=2, min_samples_leaf=4, min_samples_split=10, n_estimators=200;, score=0.547 total time=   0.6s
# [CV 3/3; 42/216] START criterion=entropy, max_depth=2, min_samples_leaf=5, min_samples_split=5, n_estimators=200
# [CV 3/3; 40/216] END criterion=entropy, max_depth=2, min_samples_leaf=5, min_samples_split=5, n_estimators=50;, score=0.444 total time=   0.1s
# [CV 1/3; 43/216] START criterion=entropy, max_depth=2, min_samples_leaf=5, min_samples_split=10, n_estimators=50
# [CV 2/3; 36/216] END criterion=entropy, max_depth=2, min_samples_leaf=4, min_samples_split=10, n_estimators=200;, score=0.532 total time=   0.7s
# [CV 2/3; 43/216] START criterion=entropy, max_depth=2, min_samples_leaf=5, min_samples_split=10, n_estimators=50
# [CV 1/3; 43/216] END criterion=entropy, max_depth=2, min_samples_leaf=5, min_samples_split=10, n_estimators=50;, score=0.542 total time=   0.1s
# [CV 3/3; 43/216] START criterion=entropy, max_depth=2, min_samples_leaf=5, min_samples_split=10, n_estimators=50
# [CV 3/3; 33/216] END criterion=entropy, max_depth=2, min_samples_leaf=4, min_samples_split=5, n_estimators=200;, score=0.467 total time=   1.0s
# [CV 1/3; 39/216] END criterion=entropy, max_depth=2, min_samples_leaf=5, min_samples_split=4, n_estimators=200;, score=0.557 total time=   0.5s
# [CV 1/3; 44/216] START criterion=entropy, max_depth=2, min_samples_leaf=5, min_samples_split=10, n_estimators=100
# [CV 2/3; 44/216] START criterion=entropy, max_depth=2, min_samples_leaf=5, min_samples_split=10, n_estimators=100
# [CV 2/3; 39/216] END criterion=entropy, max_depth=2, min_samples_leaf=5, min_samples_split=4, n_estimators=200;, score=0.547 total time=   0.5s
# [CV 3/3; 44/216] START criterion=entropy, max_depth=2, min_samples_leaf=5, min_samples_split=10, n_estimators=100
# [CV 2/3; 43/216] END criterion=entropy, max_depth=2, min_samples_leaf=5, min_samples_split=10, n_estimators=50;, score=0.547 total time=   0.1s
# [CV 1/3; 45/216] START criterion=entropy, max_depth=2, min_samples_leaf=5, min_samples_split=10, n_estimators=200
# [CV 2/3; 41/216] END criterion=entropy, max_depth=2, min_samples_leaf=5, min_samples_split=5, n_estimators=100;, score=0.532 total time=   0.3s
# [CV 2/3; 45/216] START criterion=entropy, max_depth=2, min_samples_leaf=5, min_samples_split=10, n_estimators=200
# [CV 3/3; 43/216] END criterion=entropy, max_depth=2, min_samples_leaf=5, min_samples_split=10, n_estimators=50;, score=0.442 total time=   0.1s
# [CV 3/3; 45/216] START criterion=entropy, max_depth=2, min_samples_leaf=5, min_samples_split=10, n_estimators=200
# [CV 3/3; 39/216] END criterion=entropy, max_depth=2, min_samples_leaf=5, min_samples_split=4, n_estimators=200;, score=0.449 total time=   0.5s
# [CV 1/3; 46/216] START criterion=entropy, max_depth=2, min_samples_leaf=10, min_samples_split=4, n_estimators=50
# [CV 3/3; 41/216] END criterion=entropy, max_depth=2, min_samples_leaf=5, min_samples_split=5, n_estimators=100;, score=0.432 total time=   0.5s
# [CV 2/3; 46/216] START criterion=entropy, max_depth=2, min_samples_leaf=10, min_samples_split=4, n_estimators=50[CV 1/3; 41/216] END criterion=entropy, max_depth=2, min_samples_leaf=5, min_samples_split=5, n_estimators=100;, score=0.532 total time=   0.5s
#
# [CV 3/3; 46/216] START criterion=entropy, max_depth=2, min_samples_leaf=10, min_samples_split=4, n_estimators=50
# [CV 3/3; 44/216] END criterion=entropy, max_depth=2, min_samples_leaf=5, min_samples_split=10, n_estimators=100;, score=0.444 total time=   0.3s
# [CV 1/3; 47/216] START criterion=entropy, max_depth=2, min_samples_leaf=10, min_samples_split=4, n_estimators=100
# [CV 1/3; 42/216] END criterion=entropy, max_depth=2, min_samples_leaf=5, min_samples_split=5, n_estimators=200;, score=0.542 total time=   0.6s
# [CV 2/3; 47/216] START criterion=entropy, max_depth=2, min_samples_leaf=10, min_samples_split=4, n_estimators=100
# [CV 2/3; 42/216] END criterion=entropy, max_depth=2, min_samples_leaf=5, min_samples_split=5, n_estimators=200;, score=0.562 total time=   0.6s
# [CV 3/3; 47/216] START criterion=entropy, max_depth=2, min_samples_leaf=10, min_samples_split=4, n_estimators=100
# [CV 2/3; 44/216] END criterion=entropy, max_depth=2, min_samples_leaf=5, min_samples_split=10, n_estimators=100;, score=0.516 total time=   0.4s
# [CV 1/3; 48/216] START criterion=entropy, max_depth=2, min_samples_leaf=10, min_samples_split=4, n_estimators=200
# [CV 1/3; 46/216] END criterion=entropy, max_depth=2, min_samples_leaf=10, min_samples_split=4, n_estimators=50;, score=0.586 total time=   0.3s
# [CV 2/3; 48/216] START criterion=entropy, max_depth=2, min_samples_leaf=10, min_samples_split=4, n_estimators=200
# [CV 2/3; 46/216] END criterion=entropy, max_depth=2, min_samples_leaf=10, min_samples_split=4, n_estimators=50;, score=0.467 total time=   0.2s
# [CV 3/3; 48/216] START criterion=entropy, max_depth=2, min_samples_leaf=10, min_samples_split=4, n_estimators=200
# [CV 3/3; 42/216] END criterion=entropy, max_depth=2, min_samples_leaf=5, min_samples_split=5, n_estimators=200;, score=0.467 total time=   0.6s
# [CV 1/3; 49/216] START criterion=entropy, max_depth=2, min_samples_leaf=10, min_samples_split=5, n_estimators=50
# [CV 3/3; 46/216] END criterion=entropy, max_depth=2, min_samples_leaf=10, min_samples_split=4, n_estimators=50;, score=0.449 total time=   0.2s
# [CV 2/3; 49/216] START criterion=entropy, max_depth=2, min_samples_leaf=10, min_samples_split=5, n_estimators=50
# [CV 1/3; 44/216] END criterion=entropy, max_depth=2, min_samples_leaf=5, min_samples_split=10, n_estimators=100;, score=0.516 total time=   0.5s
# [CV 3/3; 49/216] START criterion=entropy, max_depth=2, min_samples_leaf=10, min_samples_split=5, n_estimators=50
# [CV 1/3; 49/216] END criterion=entropy, max_depth=2, min_samples_leaf=10, min_samples_split=5, n_estimators=50;, score=0.629 total time=   0.1s
# [CV 1/3; 50/216] START criterion=entropy, max_depth=2, min_samples_leaf=10, min_samples_split=5, n_estimators=100
# [CV 2/3; 47/216] END criterion=entropy, max_depth=2, min_samples_leaf=10, min_samples_split=4, n_estimators=100;, score=0.516 total time=   0.3s
# [CV 2/3; 50/216] START criterion=entropy, max_depth=2, min_samples_leaf=10, min_samples_split=5, n_estimators=100
# [CV 3/3; 45/216] END criterion=entropy, max_depth=2, min_samples_leaf=5, min_samples_split=10, n_estimators=200;, score=0.444 total time=   0.5s
# [CV 3/3; 50/216] START criterion=entropy, max_depth=2, min_samples_leaf=10, min_samples_split=5, n_estimators=100
# [CV 1/3; 45/216] END criterion=entropy, max_depth=2, min_samples_leaf=5, min_samples_split=10, n_estimators=200;, score=0.543 total time=   0.6s
# [CV 1/3; 51/216] START criterion=entropy, max_depth=2, min_samples_leaf=10, min_samples_split=5, n_estimators=200
# [CV 3/3; 47/216] END criterion=entropy, max_depth=2, min_samples_leaf=10, min_samples_split=4, n_estimators=100;, score=0.432 total time=   0.3s
# [CV 2/3; 51/216] START criterion=entropy, max_depth=2, min_samples_leaf=10, min_samples_split=5, n_estimators=200
# [CV 3/3; 49/216] END criterion=entropy, max_depth=2, min_samples_leaf=10, min_samples_split=5, n_estimators=50;, score=0.455 total time=   0.1s
# [CV 3/3; 51/216] START criterion=entropy, max_depth=2, min_samples_leaf=10, min_samples_split=5, n_estimators=200[CV 1/3; 47/216] END criterion=entropy, max_depth=2, min_samples_leaf=10, min_samples_split=4, n_estimators=100;, score=0.551 total time=   0.4s
#
# [CV 1/3; 52/216] START criterion=entropy, max_depth=2, min_samples_leaf=10, min_samples_split=10, n_estimators=50
# [CV 2/3; 49/216] END criterion=entropy, max_depth=2, min_samples_leaf=10, min_samples_split=5, n_estimators=50;, score=0.560 total time=   0.3s
# [CV 2/3; 52/216] START criterion=entropy, max_depth=2, min_samples_leaf=10, min_samples_split=10, n_estimators=50
# [CV 1/3; 50/216] END criterion=entropy, max_depth=2, min_samples_leaf=10, min_samples_split=5, n_estimators=100;, score=0.562 total time=   0.2s
# [CV 3/3; 52/216] START criterion=entropy, max_depth=2, min_samples_leaf=10, min_samples_split=10, n_estimators=50
# [CV 2/3; 45/216] END criterion=entropy, max_depth=2, min_samples_leaf=5, min_samples_split=10, n_estimators=200;, score=0.505 total time=   0.8s
# [CV 1/3; 53/216] START criterion=entropy, max_depth=2, min_samples_leaf=10, min_samples_split=10, n_estimators=100
# [CV 3/3; 50/216] END criterion=entropy, max_depth=2, min_samples_leaf=10, min_samples_split=5, n_estimators=100;, score=0.424 total time=   0.3s
# [CV 2/3; 53/216] START criterion=entropy, max_depth=2, min_samples_leaf=10, min_samples_split=10, n_estimators=100
# [CV 2/3; 50/216] END criterion=entropy, max_depth=2, min_samples_leaf=10, min_samples_split=5, n_estimators=100;, score=0.467 total time=   0.3s
# [CV 3/3; 53/216] START criterion=entropy, max_depth=2, min_samples_leaf=10, min_samples_split=10, n_estimators=100
# [CV 2/3; 48/216] END criterion=entropy, max_depth=2, min_samples_leaf=10, min_samples_split=4, n_estimators=200;, score=0.526 total time=   0.6s
# [CV 1/3; 54/216] START criterion=entropy, max_depth=2, min_samples_leaf=10, min_samples_split=10, n_estimators=200
# [CV 3/3; 52/216] END criterion=entropy, max_depth=2, min_samples_leaf=10, min_samples_split=10, n_estimators=50;, score=0.449 total time=   0.2s
# [CV 2/3; 54/216] START criterion=entropy, max_depth=2, min_samples_leaf=10, min_samples_split=10, n_estimators=200
# [CV 2/3; 52/216] END criterion=entropy, max_depth=2, min_samples_leaf=10, min_samples_split=10, n_estimators=50;, score=0.449 total time=   0.3s
# [CV 3/3; 54/216] START criterion=entropy, max_depth=2, min_samples_leaf=10, min_samples_split=10, n_estimators=200
# [CV 3/3; 48/216] END criterion=entropy, max_depth=2, min_samples_leaf=10, min_samples_split=4, n_estimators=200;, score=0.455 total time=   0.6s
# [CV 1/3; 55/216] START criterion=entropy, max_depth=3, min_samples_leaf=4, min_samples_split=4, n_estimators=50
# [CV 1/3; 52/216] END criterion=entropy, max_depth=2, min_samples_leaf=10, min_samples_split=10, n_estimators=50;, score=0.574 total time=   0.3s
# [CV 2/3; 55/216] START criterion=entropy, max_depth=3, min_samples_leaf=4, min_samples_split=4, n_estimators=50
# [CV 1/3; 53/216] END criterion=entropy, max_depth=2, min_samples_leaf=10, min_samples_split=10, n_estimators=100;, score=0.521 total time=   0.3s
# [CV 3/3; 55/216] START criterion=entropy, max_depth=3, min_samples_leaf=4, min_samples_split=4, n_estimators=50
# [CV 2/3; 51/216] END criterion=entropy, max_depth=2, min_samples_leaf=10, min_samples_split=5, n_estimators=200;, score=0.516 total time=   0.5s
# [CV 1/3; 56/216] START criterion=entropy, max_depth=3, min_samples_leaf=4, min_samples_split=4, n_estimators=100
# [CV 1/3; 51/216] END criterion=entropy, max_depth=2, min_samples_leaf=10, min_samples_split=5, n_estimators=200;, score=0.557 total time=   0.5s
# [CV 2/3; 56/216] START criterion=entropy, max_depth=3, min_samples_leaf=4, min_samples_split=4, n_estimators=100
# [CV 1/3; 55/216] END criterion=entropy, max_depth=3, min_samples_leaf=4, min_samples_split=4, n_estimators=50;, score=0.583 total time=   0.1s
# [CV 3/3; 56/216] START criterion=entropy, max_depth=3, min_samples_leaf=4, min_samples_split=4, n_estimators=100
# [CV 1/3; 48/216] END criterion=entropy, max_depth=2, min_samples_leaf=10, min_samples_split=4, n_estimators=200;, score=0.565 total time=   0.8s
# [CV 1/3; 57/216] START criterion=entropy, max_depth=3, min_samples_leaf=4, min_samples_split=4, n_estimators=200
# [CV 2/3; 53/216] END criterion=entropy, max_depth=2, min_samples_leaf=10, min_samples_split=10, n_estimators=100;, score=0.526 total time=   0.3s
# [CV 2/3; 57/216] START criterion=entropy, max_depth=3, min_samples_leaf=4, min_samples_split=4, n_estimators=200
# [CV 3/3; 53/216] END criterion=entropy, max_depth=2, min_samples_leaf=10, min_samples_split=10, n_estimators=100;, score=0.467 total time=   0.3s
# [CV 3/3; 57/216] START criterion=entropy, max_depth=3, min_samples_leaf=4, min_samples_split=4, n_estimators=200
# [CV 2/3; 55/216] END criterion=entropy, max_depth=3, min_samples_leaf=4, min_samples_split=4, n_estimators=50;, score=0.547 total time=   0.2s[CV 3/3; 55/216] END criterion=entropy, max_depth=3, min_samples_leaf=4, min_samples_split=4, n_estimators=50;, score=0.478 total time=   0.1s
#
# [CV 1/3; 58/216] START criterion=entropy, max_depth=3, min_samples_leaf=4, min_samples_split=5, n_estimators=50
# [CV 2/3; 58/216] START criterion=entropy, max_depth=3, min_samples_leaf=4, min_samples_split=5, n_estimators=50
# [CV 3/3; 51/216] END criterion=entropy, max_depth=2, min_samples_leaf=10, min_samples_split=5, n_estimators=200;, score=0.460 total time=   0.6s
# [CV 3/3; 58/216] START criterion=entropy, max_depth=3, min_samples_leaf=4, min_samples_split=5, n_estimators=50
# [CV 1/3; 58/216] END criterion=entropy, max_depth=3, min_samples_leaf=4, min_samples_split=5, n_estimators=50;, score=0.635 total time=   0.1s
# [CV 1/3; 59/216] START criterion=entropy, max_depth=3, min_samples_leaf=4, min_samples_split=5, n_estimators=100
# [CV 1/3; 56/216] END criterion=entropy, max_depth=3, min_samples_leaf=4, min_samples_split=4, n_estimators=100;, score=0.549 total time=   0.3s
# [CV 2/3; 59/216] START criterion=entropy, max_depth=3, min_samples_leaf=4, min_samples_split=5, n_estimators=100
# [CV 2/3; 56/216] END criterion=entropy, max_depth=3, min_samples_leaf=4, min_samples_split=4, n_estimators=100;, score=0.583 total time=   0.2s
# [CV 3/3; 59/216] START criterion=entropy, max_depth=3, min_samples_leaf=4, min_samples_split=5, n_estimators=100
# [CV 2/3; 58/216] END criterion=entropy, max_depth=3, min_samples_leaf=4, min_samples_split=5, n_estimators=50;, score=0.590 total time=   0.2s
# [CV 1/3; 60/216] START criterion=entropy, max_depth=3, min_samples_leaf=4, min_samples_split=5, n_estimators=200
# [CV 3/3; 56/216] END criterion=entropy, max_depth=3, min_samples_leaf=4, min_samples_split=4, n_estimators=100;, score=0.478 total time=   0.3s
# [CV 2/3; 60/216] START criterion=entropy, max_depth=3, min_samples_leaf=4, min_samples_split=5, n_estimators=200
# [CV 2/3; 54/216] END criterion=entropy, max_depth=2, min_samples_leaf=10, min_samples_split=10, n_estimators=200;, score=0.542 total time=   0.5s
# [CV 3/3; 60/216] START criterion=entropy, max_depth=3, min_samples_leaf=4, min_samples_split=5, n_estimators=200
# [CV 3/3; 58/216] END criterion=entropy, max_depth=3, min_samples_leaf=4, min_samples_split=5, n_estimators=50;, score=0.478 total time=   0.2s
# [CV 1/3; 61/216] START criterion=entropy, max_depth=3, min_samples_leaf=4, min_samples_split=10, n_estimators=50
# [CV 1/3; 59/216] END criterion=entropy, max_depth=3, min_samples_leaf=4, min_samples_split=5, n_estimators=100;, score=0.615 total time=   0.3s
# [CV 2/3; 59/216] END criterion=entropy, max_depth=3, min_samples_leaf=4, min_samples_split=5, n_estimators=100;, score=0.569 total time=   0.3s
# [CV 3/3; 59/216] END criterion=entropy, max_depth=3, min_samples_leaf=4, min_samples_split=5, n_estimators=100;, score=0.478 total time=   0.3s
# [CV 2/3; 61/216] START criterion=entropy, max_depth=3, min_samples_leaf=4, min_samples_split=10, n_estimators=50
# [CV 3/3; 61/216] START criterion=entropy, max_depth=3, min_samples_leaf=4, min_samples_split=10, n_estimators=50
# [CV 1/3; 62/216] START criterion=entropy, max_depth=3, min_samples_leaf=4, min_samples_split=10, n_estimators=100
# [CV 1/3; 54/216] END criterion=entropy, max_depth=2, min_samples_leaf=10, min_samples_split=10, n_estimators=200;, score=0.536 total time=   0.7s
# [CV 2/3; 62/216] START criterion=entropy, max_depth=3, min_samples_leaf=4, min_samples_split=10, n_estimators=100
# [CV 1/3; 61/216] END criterion=entropy, max_depth=3, min_samples_leaf=4, min_samples_split=10, n_estimators=50;, score=0.621 total time=   0.1s
# [CV 3/3; 62/216] START criterion=entropy, max_depth=3, min_samples_leaf=4, min_samples_split=10, n_estimators=100
# [CV 3/3; 54/216] END criterion=entropy, max_depth=2, min_samples_leaf=10, min_samples_split=10, n_estimators=200;, score=0.455 total time=   0.7s
# [CV 1/3; 63/216] START criterion=entropy, max_depth=3, min_samples_leaf=4, min_samples_split=10, n_estimators=200
# [CV 1/3; 57/216] END criterion=entropy, max_depth=3, min_samples_leaf=4, min_samples_split=4, n_estimators=200;, score=0.596 total time=   0.6s
# [CV 2/3; 63/216] START criterion=entropy, max_depth=3, min_samples_leaf=4, min_samples_split=10, n_estimators=200
# [CV 3/3; 57/216] END criterion=entropy, max_depth=3, min_samples_leaf=4, min_samples_split=4, n_estimators=200;, score=0.478 total time=   0.6s
# [CV 3/3; 63/216] START criterion=entropy, max_depth=3, min_samples_leaf=4, min_samples_split=10, n_estimators=200
# [CV 3/3; 61/216] END criterion=entropy, max_depth=3, min_samples_leaf=4, min_samples_split=10, n_estimators=50;, score=0.457 total time=   0.2s
# [CV 2/3; 61/216] END criterion=entropy, max_depth=3, min_samples_leaf=4, min_samples_split=10, n_estimators=50;, score=0.604 total time=   0.2s
# [CV 1/3; 64/216] START criterion=entropy, max_depth=3, min_samples_leaf=5, min_samples_split=4, n_estimators=50
# [CV 2/3; 64/216] START criterion=entropy, max_depth=3, min_samples_leaf=5, min_samples_split=4, n_estimators=50
# [CV 2/3; 57/216] END criterion=entropy, max_depth=3, min_samples_leaf=4, min_samples_split=4, n_estimators=200;, score=0.596 total time=   0.7s
# [CV 3/3; 64/216] START criterion=entropy, max_depth=3, min_samples_leaf=5, min_samples_split=4, n_estimators=50
# [CV 1/3; 62/216] END criterion=entropy, max_depth=3, min_samples_leaf=4, min_samples_split=10, n_estimators=100;, score=0.590 total time=   0.3s
# [CV 1/3; 65/216] START criterion=entropy, max_depth=3, min_samples_leaf=5, min_samples_split=4, n_estimators=100
# ...
# [CV 2/3; 194/216] END criterion=gini, max_depth=4, min_samples_leaf=4, min_samples_split=5, n_estimators=100;, score=0.611 total time=   0.3s
# [CV 3/3; 198/216] START criterion=gini, max_depth=4, min_samples_leaf=4, min_samples_split=10, n_estimators=200
# [CV 1/3; 199/216] START criterion=gini, max_depth=4, min_samples_leaf=5, min_samples_split=4, n_estimators=50
# [CV 2/3; 196/216] END criterion=gini, max_depth=4, min_samples_leaf=4, min_samples_split=10, n_estimators=50;, score=0.598 total time=   0.2s
# [CV 2/3; 199/216] START criterion=gini, max_depth=4, min_samples_leaf=5, min_samples_split=4, n_estimators=50
# [CV 2/3; 192/216] END criterion=gini, max_depth=4, min_samples_leaf=4, min_samples_split=4, n_estimators=200;, score=0.590 total time=   0.7s
# [CV 3/3; 199/216] START criterion=gini, max_depth=4, min_samples_leaf=5, min_samples_split=4, n_estimators=50
# [CV 1/3; 197/216] END criterion=gini, max_depth=4, min_samples_leaf=4, min_samples_split=10, n_estimators=100;, score=0.602 total time=   0.3s
# [CV 1/3; 200/216] START criterion=gini, max_depth=4, min_samples_leaf=5, min_samples_split=4, n_estimators=100
# [CV 3/3; 197/216] END criterion=gini, max_depth=4, min_samples_leaf=4, min_samples_split=10, n_estimators=100;, score=0.505 total time=   0.2s
# [CV 2/3; 200/216] START criterion=gini, max_depth=4, min_samples_leaf=5, min_samples_split=4, n_estimators=100
# [CV 1/3; 195/216] END criterion=gini, max_depth=4, min_samples_leaf=4, min_samples_split=5, n_estimators=200;, score=0.607 total time=   0.5s
# [CV 1/3; 199/216] END criterion=gini, max_depth=4, min_samples_leaf=5, min_samples_split=4, n_estimators=50;, score=0.623 total time=   0.2s
# [CV 1/3; 201/216] START criterion=gini, max_depth=4, min_samples_leaf=5, min_samples_split=4, n_estimators=200
# [CV 3/3; 200/216] START criterion=gini, max_depth=4, min_samples_leaf=5, min_samples_split=4, n_estimators=100
# [CV 2/3; 195/216] END criterion=gini, max_depth=4, min_samples_leaf=4, min_samples_split=5, n_estimators=200;, score=0.611 total time=   0.5s
# [CV 2/3; 201/216] START criterion=gini, max_depth=4, min_samples_leaf=5, min_samples_split=4, n_estimators=200
# [CV 3/3; 199/216] END criterion=gini, max_depth=4, min_samples_leaf=5, min_samples_split=4, n_estimators=50;, score=0.474 total time=   0.1s
# [CV 2/3; 199/216] END criterion=gini, max_depth=4, min_samples_leaf=5, min_samples_split=4, n_estimators=50;, score=0.577 total time=   0.2s
# [CV 3/3; 201/216] START criterion=gini, max_depth=4, min_samples_leaf=5, min_samples_split=4, n_estimators=200
# [CV 1/3; 202/216] START criterion=gini, max_depth=4, min_samples_leaf=5, min_samples_split=5, n_estimators=50
# [CV 3/3; 195/216] END criterion=gini, max_depth=4, min_samples_leaf=4, min_samples_split=5, n_estimators=200;, score=0.500 total time=   0.6s
# [CV 2/3; 202/216] START criterion=gini, max_depth=4, min_samples_leaf=5, min_samples_split=5, n_estimators=50
# [CV 1/3; 202/216] END criterion=gini, max_depth=4, min_samples_leaf=5, min_samples_split=5, n_estimators=50;, score=0.624 total time=   0.1s
# [CV 3/3; 202/216] START criterion=gini, max_depth=4, min_samples_leaf=5, min_samples_split=5, n_estimators=50
# [CV 1/3; 200/216] END criterion=gini, max_depth=4, min_samples_leaf=5, min_samples_split=4, n_estimators=100;, score=0.574 total time=   0.3s
# [CV 1/3; 203/216] START criterion=gini, max_depth=4, min_samples_leaf=5, min_samples_split=5, n_estimators=100
# [CV 2/3; 200/216] END criterion=gini, max_depth=4, min_samples_leaf=5, min_samples_split=4, n_estimators=100;, score=0.604 total time=   0.3s
# [CV 1/3; 198/216] END criterion=gini, max_depth=4, min_samples_leaf=4, min_samples_split=10, n_estimators=200;, score=0.618 total time=   0.5s
# [CV 2/3; 203/216] START criterion=gini, max_depth=4, min_samples_leaf=5, min_samples_split=5, n_estimators=100
# [CV 3/3; 203/216] START criterion=gini, max_depth=4, min_samples_leaf=5, min_samples_split=5, n_estimators=100
# [CV 2/3; 197/216] END criterion=gini, max_depth=4, min_samples_leaf=4, min_samples_split=10, n_estimators=100;, score=0.600 total time=   0.5s
# [CV 3/3; 200/216] END criterion=gini, max_depth=4, min_samples_leaf=5, min_samples_split=4, n_estimators=100;, score=0.521 total time=   0.3s
# [CV 1/3; 204/216] START criterion=gini, max_depth=4, min_samples_leaf=5, min_samples_split=5, n_estimators=200
# [CV 2/3; 204/216] START criterion=gini, max_depth=4, min_samples_leaf=5, min_samples_split=5, n_estimators=200
# [CV 2/3; 202/216] END criterion=gini, max_depth=4, min_samples_leaf=5, min_samples_split=5, n_estimators=50;, score=0.585 total time=   0.1s
# [CV 3/3; 204/216] START criterion=gini, max_depth=4, min_samples_leaf=5, min_samples_split=5, n_estimators=200
# [CV 3/3; 198/216] END criterion=gini, max_depth=4, min_samples_leaf=4, min_samples_split=10, n_estimators=200;, score=0.521 total time=   0.5s
# [CV 1/3; 205/216] START criterion=gini, max_depth=4, min_samples_leaf=5, min_samples_split=10, n_estimators=50
# [CV 3/3; 202/216] END criterion=gini, max_depth=4, min_samples_leaf=5, min_samples_split=5, n_estimators=50;, score=0.510 total time=   0.2s
# [CV 2/3; 205/216] START criterion=gini, max_depth=4, min_samples_leaf=5, min_samples_split=10, n_estimators=50
# [CV 1/3; 205/216] END criterion=gini, max_depth=4, min_samples_leaf=5, min_samples_split=10, n_estimators=50;, score=0.569 total time=   0.1s
# [CV 3/3; 205/216] START criterion=gini, max_depth=4, min_samples_leaf=5, min_samples_split=10, n_estimators=50
# [CV 1/3; 203/216] END criterion=gini, max_depth=4, min_samples_leaf=5, min_samples_split=5, n_estimators=100;, score=0.607 total time=   0.3s
# [CV 2/3; 203/216] END criterion=gini, max_depth=4, min_samples_leaf=5, min_samples_split=5, n_estimators=100;, score=0.606 total time=   0.3s
# [CV 1/3; 206/216] START criterion=gini, max_depth=4, min_samples_leaf=5, min_samples_split=10, n_estimators=100
# [CV 2/3; 206/216] START criterion=gini, max_depth=4, min_samples_leaf=5, min_samples_split=10, n_estimators=100
# [CV 2/3; 201/216] END criterion=gini, max_depth=4, min_samples_leaf=5, min_samples_split=4, n_estimators=200;, score=0.593 total time=   0.5s
# [CV 3/3; 206/216] START criterion=gini, max_depth=4, min_samples_leaf=5, min_samples_split=10, n_estimators=100
# [CV 1/3; 201/216] END criterion=gini, max_depth=4, min_samples_leaf=5, min_samples_split=4, n_estimators=200;, score=0.607 total time=   0.6s
# [CV 1/3; 207/216] START criterion=gini, max_depth=4, min_samples_leaf=5, min_samples_split=10, n_estimators=200
# [CV 3/3; 203/216] END criterion=gini, max_depth=4, min_samples_leaf=5, min_samples_split=5, n_estimators=100;, score=0.526 total time=   0.4s
# [CV 2/3; 207/216] START criterion=gini, max_depth=4, min_samples_leaf=5, min_samples_split=10, n_estimators=200
# [CV 3/3; 201/216] END criterion=gini, max_depth=4, min_samples_leaf=5, min_samples_split=4, n_estimators=200;, score=0.505 total time=   0.5s
# [CV 3/3; 207/216] START criterion=gini, max_depth=4, min_samples_leaf=5, min_samples_split=10, n_estimators=200
# [CV 3/3; 205/216] END criterion=gini, max_depth=4, min_samples_leaf=5, min_samples_split=10, n_estimators=50;, score=0.510 total time=   0.2s
# [CV 1/3; 208/216] START criterion=gini, max_depth=4, min_samples_leaf=10, min_samples_split=4, n_estimators=50
# [CV 1/3; 208/216] END criterion=gini, max_depth=4, min_samples_leaf=10, min_samples_split=4, n_estimators=50;, score=0.606 total time=   0.1s
# [CV 2/3; 206/216] END criterion=gini, max_depth=4, min_samples_leaf=5, min_samples_split=10, n_estimators=100;, score=0.598 total time=   0.3s
# [CV 2/3; 208/216] START criterion=gini, max_depth=4, min_samples_leaf=10, min_samples_split=4, n_estimators=50
# [CV 3/3; 208/216] START criterion=gini, max_depth=4, min_samples_leaf=10, min_samples_split=4, n_estimators=50
# [CV 2/3; 198/216] END criterion=gini, max_depth=4, min_samples_leaf=4, min_samples_split=10, n_estimators=200;, score=0.604 total time=   1.0s
# [CV 1/3; 209/216] START criterion=gini, max_depth=4, min_samples_leaf=10, min_samples_split=4, n_estimators=100
# [CV 2/3; 205/216] END criterion=gini, max_depth=4, min_samples_leaf=5, min_samples_split=10, n_estimators=50;, score=0.610 total time=   0.5s
# [CV 2/3; 209/216] START criterion=gini, max_depth=4, min_samples_leaf=10, min_samples_split=4, n_estimators=100
# [CV 2/3; 208/216] END criterion=gini, max_depth=4, min_samples_leaf=10, min_samples_split=4, n_estimators=50;, score=0.630 total time=   0.1s
# [CV 3/3; 209/216] START criterion=gini, max_depth=4, min_samples_leaf=10, min_samples_split=4, n_estimators=100
# [CV 3/3; 204/216] END criterion=gini, max_depth=4, min_samples_leaf=5, min_samples_split=5, n_estimators=200;, score=0.473 total time=   0.6s
# [CV 1/3; 210/216] START criterion=gini, max_depth=4, min_samples_leaf=10, min_samples_split=4, n_estimators=200
# [CV 3/3; 208/216] END criterion=gini, max_depth=4, min_samples_leaf=10, min_samples_split=4, n_estimators=50;, score=0.495 total time=   0.2s
# [CV 2/3; 210/216] START criterion=gini, max_depth=4, min_samples_leaf=10, min_samples_split=4, n_estimators=200
# [CV 2/3; 204/216] END criterion=gini, max_depth=4, min_samples_leaf=5, min_samples_split=5, n_estimators=200;, score=0.630 total time=   0.7s
# [CV 3/3; 210/216] START criterion=gini, max_depth=4, min_samples_leaf=10, min_samples_split=4, n_estimators=200
# [CV 3/3; 206/216] END criterion=gini, max_depth=4, min_samples_leaf=5, min_samples_split=10, n_estimators=100;, score=0.500 total time=   0.5s
# [CV 1/3; 211/216] START criterion=gini, max_depth=4, min_samples_leaf=10, min_samples_split=5, n_estimators=50
# [CV 1/3; 206/216] END criterion=gini, max_depth=4, min_samples_leaf=5, min_samples_split=10, n_estimators=100;, score=0.619 total time=   0.6s
# [CV 2/3; 207/216] END criterion=gini, max_depth=4, min_samples_leaf=5, min_samples_split=10, n_estimators=200;, score=0.604 total time=   0.5s
# [CV 2/3; 211/216] START criterion=gini, max_depth=4, min_samples_leaf=10, min_samples_split=5, n_estimators=50
# [CV 3/3; 211/216] START criterion=gini, max_depth=4, min_samples_leaf=10, min_samples_split=5, n_estimators=50
# [CV 1/3; 207/216] END criterion=gini, max_depth=4, min_samples_leaf=5, min_samples_split=10, n_estimators=200;, score=0.579 total time=   0.5s
# [CV 1/3; 212/216] START criterion=gini, max_depth=4, min_samples_leaf=10, min_samples_split=5, n_estimators=100
# [CV 3/3; 207/216] END criterion=gini, max_depth=4, min_samples_leaf=5, min_samples_split=10, n_estimators=200;, score=0.473 total time=   0.5s
# [CV 2/3; 212/216] START criterion=gini, max_depth=4, min_samples_leaf=10, min_samples_split=5, n_estimators=100
# [CV 1/3; 211/216] END criterion=gini, max_depth=4, min_samples_leaf=10, min_samples_split=5, n_estimators=50;, score=0.607 total time=   0.1s
# [CV 3/3; 212/216] START criterion=gini, max_depth=4, min_samples_leaf=10, min_samples_split=5, n_estimators=100
# [CV 3/3; 209/216] END criterion=gini, max_depth=4, min_samples_leaf=10, min_samples_split=4, n_estimators=100;, score=0.478 total time=   0.3s
# [CV 1/3; 213/216] START criterion=gini, max_depth=4, min_samples_leaf=10, min_samples_split=5, n_estimators=200
# [CV 1/3; 209/216] END criterion=gini, max_depth=4, min_samples_leaf=10, min_samples_split=4, n_estimators=100;, score=0.643 total time=   0.3s
# [CV 2/3; 213/216] START criterion=gini, max_depth=4, min_samples_leaf=10, min_samples_split=5, n_estimators=200
# [CV 2/3; 211/216] END criterion=gini, max_depth=4, min_samples_leaf=10, min_samples_split=5, n_estimators=50;, score=0.574 total time=   0.1s
# [CV 3/3; 213/216] START criterion=gini, max_depth=4, min_samples_leaf=10, min_samples_split=5, n_estimators=200
# [CV 2/3; 212/216] END criterion=gini, max_depth=4, min_samples_leaf=10, min_samples_split=5, n_estimators=100;, score=0.623 total time=   0.3s
# [CV 1/3; 214/216] START criterion=gini, max_depth=4, min_samples_leaf=10, min_samples_split=10, n_estimators=50
# [CV 3/3; 212/216] END criterion=gini, max_depth=4, min_samples_leaf=10, min_samples_split=5, n_estimators=100;, score=0.500 total time=   0.3s
# [CV 2/3; 214/216] START criterion=gini, max_depth=4, min_samples_leaf=10, min_samples_split=10, n_estimators=50
# [CV 1/3; 210/216] END criterion=gini, max_depth=4, min_samples_leaf=10, min_samples_split=4, n_estimators=200;, score=0.587 total time=   0.5s
# [CV 1/3; 212/216] END criterion=gini, max_depth=4, min_samples_leaf=10, min_samples_split=5, n_estimators=100;, score=0.606 total time=   0.3s
# [CV 3/3; 214/216] START criterion=gini, max_depth=4, min_samples_leaf=10, min_samples_split=10, n_estimators=50
# [CV 1/3; 215/216] START criterion=gini, max_depth=4, min_samples_leaf=10, min_samples_split=10, n_estimators=100
# [CV 3/3; 211/216] END criterion=gini, max_depth=4, min_samples_leaf=10, min_samples_split=5, n_estimators=50;, score=0.500 total time=   0.3s
# [CV 2/3; 215/216] START criterion=gini, max_depth=4, min_samples_leaf=10, min_samples_split=10, n_estimators=100
# [CV 1/3; 214/216] END criterion=gini, max_depth=4, min_samples_leaf=10, min_samples_split=10, n_estimators=50;, score=0.638 total time=   0.1s
# [CV 3/3; 215/216] START criterion=gini, max_depth=4, min_samples_leaf=10, min_samples_split=10, n_estimators=100
# [CV 2/3; 214/216] END criterion=gini, max_depth=4, min_samples_leaf=10, min_samples_split=10, n_estimators=50;, score=0.617 total time=   0.1s
# [CV 1/3; 216/216] START criterion=gini, max_depth=4, min_samples_leaf=10, min_samples_split=10, n_estimators=200
# [CV 2/3; 210/216] END criterion=gini, max_depth=4, min_samples_leaf=10, min_samples_split=4, n_estimators=200;, score=0.604 total time=   0.6s
# [CV 1/3; 204/216] END criterion=gini, max_depth=4, min_samples_leaf=5, min_samples_split=5, n_estimators=200;, score=0.582 total time=   1.3s[CV 2/3; 216/216] START criterion=gini, max_depth=4, min_samples_leaf=10, min_samples_split=10, n_estimators=200
#
# [CV 3/3; 214/216] END criterion=gini, max_depth=4, min_samples_leaf=10, min_samples_split=10, n_estimators=50;, score=0.485 total time=   0.1s[CV 3/3; 216/216] START criterion=gini, max_depth=4, min_samples_leaf=10, min_samples_split=10, n_estimators=200
#
# [CV 2/3; 209/216] END criterion=gini, max_depth=4, min_samples_leaf=10, min_samples_split=4, n_estimators=100;, score=0.593 total time=   0.7s
# [CV 1/3; 213/216] END criterion=gini, max_depth=4, min_samples_leaf=10, min_samples_split=5, n_estimators=200;, score=0.587 total time=   0.5s
# [CV 3/3; 213/216] END criterion=gini, max_depth=4, min_samples_leaf=10, min_samples_split=5, n_estimators=200;, score=0.495 total time=   0.5s
# [CV 1/3; 215/216] END criterion=gini, max_depth=4, min_samples_leaf=10, min_samples_split=10, n_estimators=100;, score=0.569 total time=   0.3s
# [CV 3/3; 215/216] END criterion=gini, max_depth=4, min_samples_leaf=10, min_samples_split=10, n_estimators=100;, score=0.484 total time=   0.3s
# [CV 2/3; 215/216] END criterion=gini, max_depth=4, min_samples_leaf=10, min_samples_split=10, n_estimators=100;, score=0.587 total time=   0.3s
# [CV 3/3; 210/216] END criterion=gini, max_depth=4, min_samples_leaf=10, min_samples_split=4, n_estimators=200;, score=0.478 total time=   0.9s
# [CV 2/3; 213/216] END criterion=gini, max_depth=4, min_samples_leaf=10, min_samples_split=5, n_estimators=200;, score=0.593 total time=   0.7s
# [CV 1/3; 216/216] END criterion=gini, max_depth=4, min_samples_leaf=10, min_samples_split=10, n_estimators=200;, score=0.613 total time=   0.4s
# [CV 2/3; 216/216] END criterion=gini, max_depth=4, min_samples_leaf=10, min_samples_split=10, n_estimators=200;, score=0.604 total time=   0.4s
# [CV 3/3; 216/216] END criterion=gini, max_depth=4, min_samples_leaf=10, min_samples_split=10, n_estimators=200;, score=0.484 total time=   0.4s
# GridSearchCV(cv=3, estimator=RandomForestClassifier(), n_jobs=-1,
#              param_grid={'criterion': ['entropy', 'gini'],
#                          'max_depth': [1, 2, 3, 4],
#                          'min_samples_leaf': [4, 5, 10],
#                          'min_samples_split': [4, 5, 10],
#                          'n_estimators': [50, 100, 200]},
#              scoring='f1', verbose=10)

# %%
#summarize the results of your GRIDSEARCH
print('***GRIDSEARCH RESULTS***')

print("Best score: %f using %s" % (gs.best_score_, gs.best_params_))
means = gs.cv_results_['mean_test_score']
stds = gs.cv_results_['std_test_score']
params = gs.cv_results_['params']

for mean, stdev, param in zip(means, stds, params):
    print("%f (%f) with: %r" % (mean, stdev, param))
# Out:
# ***GRIDSEARCH RESULTS***
# Best score: 0.589455 using {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 4, 'min_samples_split': 5, 'n_estimators': 50}
# 0.197531 (0.152208) with: {'criterion': 'entropy', 'max_depth': 1, 'min_samples_leaf': 4, 'min_samples_split': 4, 'n_estimators': 50}
# 0.221956 (0.117077) with: {'criterion': 'entropy', 'max_depth': 1, 'min_samples_leaf': 4, 'min_samples_split': 4, 'n_estimators': 100}
# 0.197943 (0.097767) with: {'criterion': 'entropy', 'max_depth': 1, 'min_samples_leaf': 4, 'min_samples_split': 4, 'n_estimators': 200}
# 0.201083 (0.081513) with: {'criterion': 'entropy', 'max_depth': 1, 'min_samples_leaf': 4, 'min_samples_split': 5, 'n_estimators': 50}
# 0.218044 (0.126115) with: {'criterion': 'entropy', 'max_depth': 1, 'min_samples_leaf': 4, 'min_samples_split': 5, 'n_estimators': 100}
# 0.232817 (0.080256) with: {'criterion': 'entropy', 'max_depth': 1, 'min_samples_leaf': 4, 'min_samples_split': 5, 'n_estimators': 200}
# 0.239551 (0.096794) with: {'criterion': 'entropy', 'max_depth': 1, 'min_samples_leaf': 4, 'min_samples_split': 10, 'n_estimators': 50}
# 0.192489 (0.170621) with: {'criterion': 'entropy', 'max_depth': 1, 'min_samples_leaf': 4, 'min_samples_split': 10, 'n_estimators': 100}
# 0.225656 (0.097076) with: {'criterion': 'entropy', 'max_depth': 1, 'min_samples_leaf': 4, 'min_samples_split': 10, 'n_estimators': 200}
# 0.230108 (0.132600) with: {'criterion': 'entropy', 'max_depth': 1, 'min_samples_leaf': 5, 'min_samples_split': 4, 'n_estimators': 50}
# 0.200336 (0.079107) with: {'criterion': 'entropy', 'max_depth': 1, 'min_samples_leaf': 5, 'min_samples_split': 4, 'n_estimators': 100}
# 0.204686 (0.122648) with: {'criterion': 'entropy', 'max_depth': 1, 'min_samples_leaf': 5, 'min_samples_split': 4, 'n_estimators': 200}
# 0.181552 (0.102374) with: {'criterion': 'entropy', 'max_depth': 1, 'min_samples_leaf': 5, 'min_samples_split': 5, 'n_estimators': 50}
# 0.097778 (0.138279) with: {'criterion': 'entropy', 'max_depth': 1, 'min_samples_leaf': 5, 'min_samples_split': 5, 'n_estimators': 100}
# 0.193809 (0.082674) with: {'criterion': 'entropy', 'max_depth': 1, 'min_samples_leaf': 5, 'min_samples_split': 5, 'n_estimators': 200}
# 0.202764 (0.061675) with: {'criterion': 'entropy', 'max_depth': 1, 'min_samples_leaf': 5, 'min_samples_split': 10, 'n_estimators': 50}
# 0.248341 (0.111334) with: {'criterion': 'entropy', 'max_depth': 1, 'min_samples_leaf': 5, 'min_samples_split': 10, 'n_estimators': 100}
# 0.212409 (0.111877) with: {'criterion': 'entropy', 'max_depth': 1, 'min_samples_leaf': 5, 'min_samples_split': 10, 'n_estimators': 200}
# 0.179970 (0.128681) with: {'criterion': 'entropy', 'max_depth': 1, 'min_samples_leaf': 10, 'min_samples_split': 4, 'n_estimators': 50}
# 0.243881 (0.147794) with: {'criterion': 'entropy', 'max_depth': 1, 'min_samples_leaf': 10, 'min_samples_split': 4, 'n_estimators': 100}
# 0.221714 (0.116150) with: {'criterion': 'entropy', 'max_depth': 1, 'min_samples_leaf': 10, 'min_samples_split': 4, 'n_estimators': 200}
# 0.136264 (0.105677) with: {'criterion': 'entropy', 'max_depth': 1, 'min_samples_leaf': 10, 'min_samples_split': 5, 'n_estimators': 50}
# 0.188721 (0.099275) with: {'criterion': 'entropy', 'max_depth': 1, 'min_samples_leaf': 10, 'min_samples_split': 5, 'n_estimators': 100}
# 0.239117 (0.134096) with: {'criterion': 'entropy', 'max_depth': 1, 'min_samples_leaf': 10, 'min_samples_split': 5, 'n_estimators': 200}
# 0.139633 (0.111911) with: {'criterion': 'entropy', 'max_depth': 1, 'min_samples_leaf': 10, 'min_samples_split': 10, 'n_estimators': 50}
# 0.183933 (0.108541) with: {'criterion': 'entropy', 'max_depth': 1, 'min_samples_leaf': 10, 'min_samples_split': 10, 'n_estimators': 100}
# 0.197151 (0.102044) with: {'criterion': 'entropy', 'max_depth': 1, 'min_samples_leaf': 10, 'min_samples_split': 10, 'n_estimators': 200}
# 0.509259 (0.057078) with: {'criterion': 'entropy', 'max_depth': 2, 'min_samples_leaf': 4, 'min_samples_split': 4, 'n_estimators': 50}
# 0.526515 (0.071936) with: {'criterion': 'entropy', 'max_depth': 2, 'min_samples_leaf': 4, 'min_samples_split': 4, 'n_estimators': 100}
# 0.496331 (0.042889) with: {'criterion': 'entropy', 'max_depth': 2, 'min_samples_leaf': 4, 'min_samples_split': 4, 'n_estimators': 200}
# 0.461339 (0.049947) with: {'criterion': 'entropy', 'max_depth': 2, 'min_samples_leaf': 4, 'min_samples_split': 5, 'n_estimators': 50}
# 0.502770 (0.035212) with: {'criterion': 'entropy', 'max_depth': 2, 'min_samples_leaf': 4, 'min_samples_split': 5, 'n_estimators': 100}
# 0.497735 (0.026728) with: {'criterion': 'entropy', 'max_depth': 2, 'min_samples_leaf': 4, 'min_samples_split': 5, 'n_estimators': 200}
# 0.517638 (0.045033) with: {'criterion': 'entropy', 'max_depth': 2, 'min_samples_leaf': 4, 'min_samples_split': 10, 'n_estimators': 50}
# 0.509491 (0.064563) with: {'criterion': 'entropy', 'max_depth': 2, 'min_samples_leaf': 4, 'min_samples_split': 10, 'n_estimators': 100}
# 0.507048 (0.046524) with: {'criterion': 'entropy', 'max_depth': 2, 'min_samples_leaf': 4, 'min_samples_split': 10, 'n_estimators': 200}
# 0.536188 (0.033195) with: {'criterion': 'entropy', 'max_depth': 2, 'min_samples_leaf': 5, 'min_samples_split': 4, 'n_estimators': 50}
# 0.504281 (0.039624) with: {'criterion': 'entropy', 'max_depth': 2, 'min_samples_leaf': 5, 'min_samples_split': 4, 'n_estimators': 100}
# 0.517836 (0.048514) with: {'criterion': 'entropy', 'max_depth': 2, 'min_samples_leaf': 5, 'min_samples_split': 4, 'n_estimators': 200}
# 0.513925 (0.060467) with: {'criterion': 'entropy', 'max_depth': 2, 'min_samples_leaf': 5, 'min_samples_split': 5, 'n_estimators': 50}
# 0.498549 (0.047186) with: {'criterion': 'entropy', 'max_depth': 2, 'min_samples_leaf': 5, 'min_samples_split': 5, 'n_estimators': 100}
# 0.523611 (0.041154) with: {'criterion': 'entropy', 'max_depth': 2, 'min_samples_leaf': 5, 'min_samples_split': 5, 'n_estimators': 200}
# 0.510299 (0.048449) with: {'criterion': 'entropy', 'max_depth': 2, 'min_samples_leaf': 5, 'min_samples_split': 10, 'n_estimators': 50}
# 0.492234 (0.033792) with: {'criterion': 'entropy', 'max_depth': 2, 'min_samples_leaf': 5, 'min_samples_split': 10, 'n_estimators': 100}
# 0.497806 (0.040794) with: {'criterion': 'entropy', 'max_depth': 2, 'min_samples_leaf': 5, 'min_samples_split': 10, 'n_estimators': 200}
# 0.500654 (0.060658) with: {'criterion': 'entropy', 'max_depth': 2, 'min_samples_leaf': 10, 'min_samples_split': 4, 'n_estimators': 50}
# 0.499656 (0.050039) with: {'criterion': 'entropy', 'max_depth': 2, 'min_samples_leaf': 10, 'min_samples_split': 4, 'n_estimators': 100}
# 0.515360 (0.045841) with: {'criterion': 'entropy', 'max_depth': 2, 'min_samples_leaf': 10, 'min_samples_split': 4, 'n_estimators': 200}
# 0.547706 (0.071576) with: {'criterion': 'entropy', 'max_depth': 2, 'min_samples_leaf': 10, 'min_samples_split': 5, 'n_estimators': 50}
# 0.484232 (0.058078) with: {'criterion': 'entropy', 'max_depth': 2, 'min_samples_leaf': 10, 'min_samples_split': 5, 'n_estimators': 100}
# 0.510867 (0.039746) with: {'criterion': 'entropy', 'max_depth': 2, 'min_samples_leaf': 10, 'min_samples_split': 5, 'n_estimators': 200}
# 0.491045 (0.058840) with: {'criterion': 'entropy', 'max_depth': 2, 'min_samples_leaf': 10, 'min_samples_split': 10, 'n_estimators': 50}
# 0.504605 (0.026920) with: {'criterion': 'entropy', 'max_depth': 2, 'min_samples_leaf': 10, 'min_samples_split': 10, 'n_estimators': 100}
# 0.510765 (0.039818) with: {'criterion': 'entropy', 'max_depth': 2, 'min_samples_leaf': 10, 'min_samples_split': 10, 'n_estimators': 200}
# 0.536051 (0.043311) with: {'criterion': 'entropy', 'max_depth': 3, 'min_samples_leaf': 4, 'min_samples_split': 4, 'n_estimators': 50}
# 0.536602 (0.043462) with: {'criterion': 'entropy', 'max_depth': 3, 'min_samples_leaf': 4, 'min_samples_split': 4, 'n_estimators': 100}
# 0.556856 (0.055575) with: {'criterion': 'entropy', 'max_depth': 3, 'min_samples_leaf': 4, 'min_samples_split': 4, 'n_estimators': 200}
# 0.567784 (0.065817) with: {'criterion': 'entropy', 'max_depth': 3, 'min_samples_leaf': 4, 'min_samples_split': 5, 'n_estimators': 50}
# 0.554091 (0.056916) with: {'criterion': 'entropy', 'max_depth': 3, 'min_samples_leaf': 4, 'min_samples_split': 5, 'n_estimators': 100}
# 0.551615 (0.052082) with: {'criterion': 'entropy', 'max_depth': 3, 'min_samples_leaf': 4, 'min_samples_split': 5, 'n_estimators': 200}
# 0.560552 (0.073910) with: {'criterion': 'entropy', 'max_depth': 3, 'min_samples_leaf': 4, 'min_samples_split': 10, 'n_estimators': 50}
# 0.560418 (0.046581) with: {'criterion': 'entropy', 'max_depth': 3, 'min_samples_leaf': 4, 'min_samples_split': 10, 'n_estimators': 100}
# 0.561313 (0.058980) with: {'criterion': 'entropy', 'max_depth': 3, 'min_samples_leaf': 4, 'min_samples_split': 10, 'n_estimators': 200}
# 0.535837 (0.029161) with: {'criterion': 'entropy', 'max_depth': 3, 'min_samples_leaf': 5, 'min_samples_split': 4, 'n_estimators': 50}
# 0.551472 (0.052186) with: {'criterion': 'entropy', 'max_depth': 3, 'min_samples_leaf': 5, 'min_samples_split': 4, 'n_estimators': 100}
# 0.564453 (0.053312) with: {'criterion': 'entropy', 'max_depth': 3, 'min_samples_leaf': 5, 'min_samples_split': 4, 'n_estimators': 200}
# 0.563004 (0.060031) with: {'criterion': 'entropy', 'max_depth': 3, 'min_samples_leaf': 5, 'min_samples_split': 5, 'n_estimators': 50}
# 0.564649 (0.063149) with: {'criterion': 'entropy', 'max_depth': 3, 'min_samples_leaf': 5, 'min_samples_split': 5, 'n_estimators': 100}
# 0.564850 (0.049755) with: {'criterion': 'entropy', 'max_depth': 3, 'min_samples_leaf': 5, 'min_samples_split': 5, 'n_estimators': 200}
# 0.550854 (0.070283) with: {'criterion': 'entropy', 'max_depth': 3, 'min_samples_leaf': 5, 'min_samples_split': 10, 'n_estimators': 50}
# 0.564806 (0.054609) with: {'criterion': 'entropy', 'max_depth': 3, 'min_samples_leaf': 5, 'min_samples_split': 10, 'n_estimators': 100}
# 0.555994 (0.051859) with: {'criterion': 'entropy', 'max_depth': 3, 'min_samples_leaf': 5, 'min_samples_split': 10, 'n_estimators': 200}
# 0.557069 (0.044406) with: {'criterion': 'entropy', 'max_depth': 3, 'min_samples_leaf': 10, 'min_samples_split': 4, 'n_estimators': 50}
# 0.553261 (0.041719) with: {'criterion': 'entropy', 'max_depth': 3, 'min_samples_leaf': 10, 'min_samples_split': 4, 'n_estimators': 100}
# 0.545683 (0.044458) with: {'criterion': 'entropy', 'max_depth': 3, 'min_samples_leaf': 10, 'min_samples_split': 4, 'n_estimators': 200}
# 0.547732 (0.037464) with: {'criterion': 'entropy', 'max_depth': 3, 'min_samples_leaf': 10, 'min_samples_split': 5, 'n_estimators': 50}
# 0.550245 (0.037050) with: {'criterion': 'entropy', 'max_depth': 3, 'min_samples_leaf': 10, 'min_samples_split': 5, 'n_estimators': 100}
# 0.553188 (0.058161) with: {'criterion': 'entropy', 'max_depth': 3, 'min_samples_leaf': 10, 'min_samples_split': 5, 'n_estimators': 200}
# 0.559988 (0.066030) with: {'criterion': 'entropy', 'max_depth': 3, 'min_samples_leaf': 10, 'min_samples_split': 10, 'n_estimators': 50}
# 0.572743 (0.056697) with: {'criterion': 'entropy', 'max_depth': 3, 'min_samples_leaf': 10, 'min_samples_split': 10, 'n_estimators': 100}
# 0.552313 (0.052658) with: {'criterion': 'entropy', 'max_depth': 3, 'min_samples_leaf': 10, 'min_samples_split': 10, 'n_estimators': 200}
# 0.564899 (0.049716) with: {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 4, 'min_samples_split': 4, 'n_estimators': 50}
# 0.580962 (0.061007) with: {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 4, 'min_samples_split': 4, 'n_estimators': 100}
# 0.554917 (0.033172) with: {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 4, 'min_samples_split': 4, 'n_estimators': 200}
# 0.578112 (0.037438) with: {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 4, 'min_samples_split': 5, 'n_estimators': 50}
# 0.572501 (0.058588) with: {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 4, 'min_samples_split': 5, 'n_estimators': 100}
# 0.565771 (0.043738) with: {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 4, 'min_samples_split': 5, 'n_estimators': 200}
# 0.558974 (0.042752) with: {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 4, 'min_samples_split': 10, 'n_estimators': 50}
# 0.576478 (0.054106) with: {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 4, 'min_samples_split': 10, 'n_estimators': 100}
# 0.557532 (0.063976) with: {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 4, 'min_samples_split': 10, 'n_estimators': 200}
# 0.562551 (0.065822) with: {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 5, 'min_samples_split': 4, 'n_estimators': 50}
# 0.565839 (0.047910) with: {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 5, 'min_samples_split': 4, 'n_estimators': 100}
# 0.570366 (0.044593) with: {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 5, 'min_samples_split': 4, 'n_estimators': 200}
# 0.565410 (0.039753) with: {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 5, 'min_samples_split': 5, 'n_estimators': 50}
# 0.582438 (0.050892) with: {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 5, 'min_samples_split': 5, 'n_estimators': 100}
# 0.576704 (0.039513) with: {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 5, 'min_samples_split': 5, 'n_estimators': 200}
# 0.586631 (0.057567) with: {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 5, 'min_samples_split': 10, 'n_estimators': 50}
# 0.545011 (0.036284) with: {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 5, 'min_samples_split': 10, 'n_estimators': 100}
# 0.560507 (0.046937) with: {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 5, 'min_samples_split': 10, 'n_estimators': 200}
# 0.574047 (0.068207) with: {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 10, 'min_samples_split': 4, 'n_estimators': 50}
# 0.568282 (0.059451) with: {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 10, 'min_samples_split': 4, 'n_estimators': 100}
# 0.571471 (0.043043) with: {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 10, 'min_samples_split': 4, 'n_estimators': 200}
# 0.571647 (0.057890) with: {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 10, 'min_samples_split': 5, 'n_estimators': 50}
# 0.572000 (0.051888) with: {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 10, 'min_samples_split': 5, 'n_estimators': 100}
# 0.568082 (0.055744) with: {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 10, 'min_samples_split': 5, 'n_estimators': 200}
# 0.574259 (0.049861) with: {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 10, 'min_samples_split': 10, 'n_estimators': 50}
# 0.568957 (0.063590) with: {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 10, 'min_samples_split': 10, 'n_estimators': 100}
# 0.565455 (0.046508) with: {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 10, 'min_samples_split': 10, 'n_estimators': 200}
# 0.214665 (0.110118) with: {'criterion': 'gini', 'max_depth': 1, 'min_samples_leaf': 4, 'min_samples_split': 4, 'n_estimators': 50}
# 0.273210 (0.055708) with: {'criterion': 'gini', 'max_depth': 1, 'min_samples_leaf': 4, 'min_samples_split': 4, 'n_estimators': 100}
# 0.310792 (0.100649) with: {'criterion': 'gini', 'max_depth': 1, 'min_samples_leaf': 4, 'min_samples_split': 4, 'n_estimators': 200}
# 0.170785 (0.094686) with: {'criterion': 'gini', 'max_depth': 1, 'min_samples_leaf': 4, 'min_samples_split': 5, 'n_estimators': 50}
# 0.303333 (0.034748) with: {'criterion': 'gini', 'max_depth': 1, 'min_samples_leaf': 4, 'min_samples_split': 5, 'n_estimators': 100}
# 0.192006 (0.085267) with: {'criterion': 'gini', 'max_depth': 1, 'min_samples_leaf': 4, 'min_samples_split': 5, 'n_estimators': 200}
# 0.195683 (0.109121) with: {'criterion': 'gini', 'max_depth': 1, 'min_samples_leaf': 4, 'min_samples_split': 10, 'n_estimators': 50}
# 0.288254 (0.093383) with: {'criterion': 'gini', 'max_depth': 1, 'min_samples_leaf': 4, 'min_samples_split': 10, 'n_estimators': 100}
# 0.238120 (0.132813) with: {'criterion': 'gini', 'max_depth': 1, 'min_samples_leaf': 4, 'min_samples_split': 10, 'n_estimators': 200}
# 0.274275 (0.066270) with: {'criterion': 'gini', 'max_depth': 1, 'min_samples_leaf': 5, 'min_samples_split': 4, 'n_estimators': 50}
# 0.275748 (0.038583) with: {'criterion': 'gini', 'max_depth': 1, 'min_samples_leaf': 5, 'min_samples_split': 4, 'n_estimators': 100}
# 0.219390 (0.053288) with: {'criterion': 'gini', 'max_depth': 1, 'min_samples_leaf': 5, 'min_samples_split': 4, 'n_estimators': 200}
# 0.281674 (0.177597) with: {'criterion': 'gini', 'max_depth': 1, 'min_samples_leaf': 5, 'min_samples_split': 5, 'n_estimators': 50}
# 0.196303 (0.114075) with: {'criterion': 'gini', 'max_depth': 1, 'min_samples_leaf': 5, 'min_samples_split': 5, 'n_estimators': 100}
# 0.267075 (0.112826) with: {'criterion': 'gini', 'max_depth': 1, 'min_samples_leaf': 5, 'min_samples_split': 5, 'n_estimators': 200}
# 0.200501 (0.142306) with: {'criterion': 'gini', 'max_depth': 1, 'min_samples_leaf': 5, 'min_samples_split': 10, 'n_estimators': 50}
# 0.305746 (0.046079) with: {'criterion': 'gini', 'max_depth': 1, 'min_samples_leaf': 5, 'min_samples_split': 10, 'n_estimators': 100}
# 0.234771 (0.082819) with: {'criterion': 'gini', 'max_depth': 1, 'min_samples_leaf': 5, 'min_samples_split': 10, 'n_estimators': 200}
# 0.258537 (0.167181) with: {'criterion': 'gini', 'max_depth': 1, 'min_samples_leaf': 10, 'min_samples_split': 4, 'n_estimators': 50}
# 0.153528 (0.117266) with: {'criterion': 'gini', 'max_depth': 1, 'min_samples_leaf': 10, 'min_samples_split': 4, 'n_estimators': 100}
# 0.251816 (0.046893) with: {'criterion': 'gini', 'max_depth': 1, 'min_samples_leaf': 10, 'min_samples_split': 4, 'n_estimators': 200}
# 0.266306 (0.065181) with: {'criterion': 'gini', 'max_depth': 1, 'min_samples_leaf': 10, 'min_samples_split': 5, 'n_estimators': 50}
# 0.210390 (0.091045) with: {'criterion': 'gini', 'max_depth': 1, 'min_samples_leaf': 10, 'min_samples_split': 5, 'n_estimators': 100}
# 0.290738 (0.085971) with: {'criterion': 'gini', 'max_depth': 1, 'min_samples_leaf': 10, 'min_samples_split': 5, 'n_estimators': 200}
# 0.258382 (0.045892) with: {'criterion': 'gini', 'max_depth': 1, 'min_samples_leaf': 10, 'min_samples_split': 10, 'n_estimators': 50}
# 0.332716 (0.049500) with: {'criterion': 'gini', 'max_depth': 1, 'min_samples_leaf': 10, 'min_samples_split': 10, 'n_estimators': 100}
# 0.275368 (0.143837) with: {'criterion': 'gini', 'max_depth': 1, 'min_samples_leaf': 10, 'min_samples_split': 10, 'n_estimators': 200}
# 0.539290 (0.033411) with: {'criterion': 'gini', 'max_depth': 2, 'min_samples_leaf': 4, 'min_samples_split': 4, 'n_estimators': 50}
# 0.516499 (0.047449) with: {'criterion': 'gini', 'max_depth': 2, 'min_samples_leaf': 4, 'min_samples_split': 4, 'n_estimators': 100}
# 0.533786 (0.051444) with: {'criterion': 'gini', 'max_depth': 2, 'min_samples_leaf': 4, 'min_samples_split': 4, 'n_estimators': 200}
# 0.507915 (0.044911) with: {'criterion': 'gini', 'max_depth': 2, 'min_samples_leaf': 4, 'min_samples_split': 5, 'n_estimators': 50}
# 0.522523 (0.048644) with: {'criterion': 'gini', 'max_depth': 2, 'min_samples_leaf': 4, 'min_samples_split': 5, 'n_estimators': 100}
# 0.517883 (0.048406) with: {'criterion': 'gini', 'max_depth': 2, 'min_samples_leaf': 4, 'min_samples_split': 5, 'n_estimators': 200}
# 0.531228 (0.054888) with: {'criterion': 'gini', 'max_depth': 2, 'min_samples_leaf': 4, 'min_samples_split': 10, 'n_estimators': 50}
# 0.521780 (0.058445) with: {'criterion': 'gini', 'max_depth': 2, 'min_samples_leaf': 4, 'min_samples_split': 10, 'n_estimators': 100}
# 0.529233 (0.041435) with: {'criterion': 'gini', 'max_depth': 2, 'min_samples_leaf': 4, 'min_samples_split': 10, 'n_estimators': 200}
# 0.520451 (0.053915) with: {'criterion': 'gini', 'max_depth': 2, 'min_samples_leaf': 5, 'min_samples_split': 4, 'n_estimators': 50}
# 0.539270 (0.060486) with: {'criterion': 'gini', 'max_depth': 2, 'min_samples_leaf': 5, 'min_samples_split': 4, 'n_estimators': 100}
# 0.498765 (0.038021) with: {'criterion': 'gini', 'max_depth': 2, 'min_samples_leaf': 5, 'min_samples_split': 4, 'n_estimators': 200}
# 0.528357 (0.057755) with: {'criterion': 'gini', 'max_depth': 2, 'min_samples_leaf': 5, 'min_samples_split': 5, 'n_estimators': 50}
# 0.523373 (0.074540) with: {'criterion': 'gini', 'max_depth': 2, 'min_samples_leaf': 5, 'min_samples_split': 5, 'n_estimators': 100}
# 0.536436 (0.058109) with: {'criterion': 'gini', 'max_depth': 2, 'min_samples_leaf': 5, 'min_samples_split': 5, 'n_estimators': 200}
# 0.525550 (0.033472) with: {'criterion': 'gini', 'max_depth': 2, 'min_samples_leaf': 5, 'min_samples_split': 10, 'n_estimators': 50}
# 0.538399 (0.059345) with: {'criterion': 'gini', 'max_depth': 2, 'min_samples_leaf': 5, 'min_samples_split': 10, 'n_estimators': 100}
# 0.526303 (0.058684) with: {'criterion': 'gini', 'max_depth': 2, 'min_samples_leaf': 5, 'min_samples_split': 10, 'n_estimators': 200}
# 0.520178 (0.063843) with: {'criterion': 'gini', 'max_depth': 2, 'min_samples_leaf': 10, 'min_samples_split': 4, 'n_estimators': 50}
# 0.523090 (0.070494) with: {'criterion': 'gini', 'max_depth': 2, 'min_samples_leaf': 10, 'min_samples_split': 4, 'n_estimators': 100}
# 0.532659 (0.060569) with: {'criterion': 'gini', 'max_depth': 2, 'min_samples_leaf': 10, 'min_samples_split': 4, 'n_estimators': 200}
# 0.505168 (0.036642) with: {'criterion': 'gini', 'max_depth': 2, 'min_samples_leaf': 10, 'min_samples_split': 5, 'n_estimators': 50}
# 0.519010 (0.053227) with: {'criterion': 'gini', 'max_depth': 2, 'min_samples_leaf': 10, 'min_samples_split': 5, 'n_estimators': 100}
# 0.529300 (0.049531) with: {'criterion': 'gini', 'max_depth': 2, 'min_samples_leaf': 10, 'min_samples_split': 5, 'n_estimators': 200}
# 0.515389 (0.062569) with: {'criterion': 'gini', 'max_depth': 2, 'min_samples_leaf': 10, 'min_samples_split': 10, 'n_estimators': 50}
# 0.522807 (0.049170) with: {'criterion': 'gini', 'max_depth': 2, 'min_samples_leaf': 10, 'min_samples_split': 10, 'n_estimators': 100}
# 0.538564 (0.027532) with: {'criterion': 'gini', 'max_depth': 2, 'min_samples_leaf': 10, 'min_samples_split': 10, 'n_estimators': 200}
# 0.558669 (0.064560) with: {'criterion': 'gini', 'max_depth': 3, 'min_samples_leaf': 4, 'min_samples_split': 4, 'n_estimators': 50}
# 0.565462 (0.048024) with: {'criterion': 'gini', 'max_depth': 3, 'min_samples_leaf': 4, 'min_samples_split': 4, 'n_estimators': 100}
# 0.553110 (0.056282) with: {'criterion': 'gini', 'max_depth': 3, 'min_samples_leaf': 4, 'min_samples_split': 4, 'n_estimators': 200}
# 0.541863 (0.052154) with: {'criterion': 'gini', 'max_depth': 3, 'min_samples_leaf': 4, 'min_samples_split': 5, 'n_estimators': 50}
# 0.556723 (0.051768) with: {'criterion': 'gini', 'max_depth': 3, 'min_samples_leaf': 4, 'min_samples_split': 5, 'n_estimators': 100}
# 0.557778 (0.044667) with: {'criterion': 'gini', 'max_depth': 3, 'min_samples_leaf': 4, 'min_samples_split': 5, 'n_estimators': 200}
# 0.546207 (0.064883) with: {'criterion': 'gini', 'max_depth': 3, 'min_samples_leaf': 4, 'min_samples_split': 10, 'n_estimators': 50}
# 0.573936 (0.041238) with: {'criterion': 'gini', 'max_depth': 3, 'min_samples_leaf': 4, 'min_samples_split': 10, 'n_estimators': 100}
# 0.567999 (0.048319) with: {'criterion': 'gini', 'max_depth': 3, 'min_samples_leaf': 4, 'min_samples_split': 10, 'n_estimators': 200}
# 0.559722 (0.057490) with: {'criterion': 'gini', 'max_depth': 3, 'min_samples_leaf': 5, 'min_samples_split': 4, 'n_estimators': 50}
# 0.549632 (0.039939) with: {'criterion': 'gini', 'max_depth': 3, 'min_samples_leaf': 5, 'min_samples_split': 4, 'n_estimators': 100}
# 0.567521 (0.059400) with: {'criterion': 'gini', 'max_depth': 3, 'min_samples_leaf': 5, 'min_samples_split': 4, 'n_estimators': 200}
# 0.565473 (0.069500) with: {'criterion': 'gini', 'max_depth': 3, 'min_samples_leaf': 5, 'min_samples_split': 5, 'n_estimators': 50}
# 0.547681 (0.050357) with: {'criterion': 'gini', 'max_depth': 3, 'min_samples_leaf': 5, 'min_samples_split': 5, 'n_estimators': 100}
# 0.563126 (0.057203) with: {'criterion': 'gini', 'max_depth': 3, 'min_samples_leaf': 5, 'min_samples_split': 5, 'n_estimators': 200}
# 0.557031 (0.046943) with: {'criterion': 'gini', 'max_depth': 3, 'min_samples_leaf': 5, 'min_samples_split': 10, 'n_estimators': 50}
# 0.549510 (0.066058) with: {'criterion': 'gini', 'max_depth': 3, 'min_samples_leaf': 5, 'min_samples_split': 10, 'n_estimators': 100}
# 0.542038 (0.053345) with: {'criterion': 'gini', 'max_depth': 3, 'min_samples_leaf': 5, 'min_samples_split': 10, 'n_estimators': 200}
# 0.563933 (0.069151) with: {'criterion': 'gini', 'max_depth': 3, 'min_samples_leaf': 10, 'min_samples_split': 4, 'n_estimators': 50}
# 0.575767 (0.061140) with: {'criterion': 'gini', 'max_depth': 3, 'min_samples_leaf': 10, 'min_samples_split': 4, 'n_estimators': 100}
# 0.545433 (0.058193) with: {'criterion': 'gini', 'max_depth': 3, 'min_samples_leaf': 10, 'min_samples_split': 4, 'n_estimators': 200}
# 0.564669 (0.064862) with: {'criterion': 'gini', 'max_depth': 3, 'min_samples_leaf': 10, 'min_samples_split': 5, 'n_estimators': 50}
# 0.563544 (0.064763) with: {'criterion': 'gini', 'max_depth': 3, 'min_samples_leaf': 10, 'min_samples_split': 5, 'n_estimators': 100}
# 0.554223 (0.061995) with: {'criterion': 'gini', 'max_depth': 3, 'min_samples_leaf': 10, 'min_samples_split': 5, 'n_estimators': 200}
# 0.569480 (0.081250) with: {'criterion': 'gini', 'max_depth': 3, 'min_samples_leaf': 10, 'min_samples_split': 10, 'n_estimators': 50}
# 0.559356 (0.034462) with: {'criterion': 'gini', 'max_depth': 3, 'min_samples_leaf': 10, 'min_samples_split': 10, 'n_estimators': 100}
# 0.556094 (0.052850) with: {'criterion': 'gini', 'max_depth': 3, 'min_samples_leaf': 10, 'min_samples_split': 10, 'n_estimators': 200}
# 0.563392 (0.059556) with: {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 4, 'min_samples_split': 4, 'n_estimators': 50}
# 0.569464 (0.040013) with: {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 4, 'min_samples_split': 4, 'n_estimators': 100}
# 0.568647 (0.037806) with: {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 4, 'min_samples_split': 4, 'n_estimators': 200}
# 0.589455 (0.048908) with: {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 4, 'min_samples_split': 5, 'n_estimators': 50}
# 0.573799 (0.071983) with: {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 4, 'min_samples_split': 5, 'n_estimators': 100}
# 0.572751 (0.051468) with: {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 4, 'min_samples_split': 5, 'n_estimators': 200}
# 0.571220 (0.066937) with: {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 4, 'min_samples_split': 10, 'n_estimators': 50}
# 0.569011 (0.045082) with: {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 4, 'min_samples_split': 10, 'n_estimators': 100}
# 0.580930 (0.042900) with: {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 4, 'min_samples_split': 10, 'n_estimators': 200}
# 0.557930 (0.062061) with: {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 5, 'min_samples_split': 4, 'n_estimators': 50}
# 0.566227 (0.034312) with: {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 5, 'min_samples_split': 4, 'n_estimators': 100}
# 0.568333 (0.044991) with: {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 5, 'min_samples_split': 4, 'n_estimators': 200}
# 0.572988 (0.047156) with: {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 5, 'min_samples_split': 5, 'n_estimators': 50}
# 0.579654 (0.037722) with: {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 5, 'min_samples_split': 5, 'n_estimators': 100}
# 0.561522 (0.065487) with: {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 5, 'min_samples_split': 5, 'n_estimators': 200}
# 0.562845 (0.040766) with: {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 5, 'min_samples_split': 10, 'n_estimators': 50}
# 0.572533 (0.052023) with: {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 5, 'min_samples_split': 10, 'n_estimators': 100}
# 0.552110 (0.056732) with: {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 5, 'min_samples_split': 10, 'n_estimators': 200}
# 0.576660 (0.058684) with: {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 10, 'min_samples_split': 4, 'n_estimators': 50}
# 0.571237 (0.068872) with: {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 10, 'min_samples_split': 4, 'n_estimators': 100}
# 0.556397 (0.055665) with: {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 10, 'min_samples_split': 4, 'n_estimators': 200}
# 0.560406 (0.044796) with: {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 10, 'min_samples_split': 5, 'n_estimators': 50}
# 0.576049 (0.054228) with: {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 10, 'min_samples_split': 5, 'n_estimators': 100}
# 0.558198 (0.044852) with: {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 10, 'min_samples_split': 5, 'n_estimators': 200}
# 0.579867 (0.067739) with: {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 10, 'min_samples_split': 10, 'n_estimators': 50}
# 0.546725 (0.044834) with: {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 10, 'min_samples_split': 10, 'n_estimators': 100}
# 0.566866 (0.058557) with: {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 10, 'min_samples_split': 10, 'n_estimators': 200}

# %%
#TEST ON YOUR TEST SET
best_model = gs.best_estimator_
y_pred = best_model.predict(X_test)

# %%
from sklearn.metrics import classification_report

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.76      0.89      0.82       150
#            1       0.70      0.47      0.56        81
#
#     accuracy                           0.74       231
#    macro avg       0.73      0.68      0.69       231
# weighted avg       0.74      0.74      0.73       231

# %%
# Plot confusion matrix
from sklearn.metrics import confusion_matrix
sns.heatmap(confusion_matrix(y_test, y_pred), annot=True, fmt='d', cmap="Reds", cbar=False)
plt.show()

# %%
from sklearn.ensemble import RandomForestClassifier

rand_forest = RandomForestClassifier(n_estimators=50, criterion='gini', max_depth=4, min_samples_split=5, min_samples_leaf=4)
rand_forest.fit(X_train, y_train)

y_pred = rand_forest.predict(X_test)

# %%
# ROC curve

from sklearn import metrics

y_probs = rand_forest.predict_proba(X_test) #predict_proba gives the probabilities for the target (0 and 1 in your case)

fpr, tpr, thresholds=metrics.roc_curve(y_test,  y_probs[:,1])

import matplotlib.pyplot as plt
plt.plot(fpr, tpr, label='ROC')
plt.plot([0, 1], [0, 1], color='darkblue', linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend()
plt.show()

auc = metrics.roc_auc_score(y_test, y_probs[:,1])
print('AUC: %.2f' % auc)
# Out:
# AUC: 0.85

# %%
sns.barplot(x=X_train.columns, y=rand_forest.feature_importances_, palette="Blues_d")
# Out:
# /tmp/ipykernel_1020/1772128828.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=X_train.columns, y=rand_forest.feature_importances_, palette="Blues_d")
# <Axes: xlabel='None'>

# %% [markdown]
# ## Adaboost

# %% [markdown]
# ![Adab](adab.png)

# %% [markdown]
# error = sum of the weights associated to the incorrectly classified samples. error $\in [0,1]$

# %%
from sklearn.ensemble import AdaBoostClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn import metrics

adaboost = AdaBoostClassifier(n_estimators=100, estimator=DecisionTreeClassifier(max_depth=3))
adaboost.fit(X_train, y_train)

y_pred = adaboost.predict(X_test)

y_pred_train = adaboost.predict(X_test)
print("f1_score: ", metrics.f1_score(y_test, y_pred))
# Out:
# f1_score:  0.6623376623376623

# %%
## from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import GridSearchCV

classifier= AdaBoostClassifier()
parameters = {'n_estimators' : [50, 100, 200],
    'learning_rate' : [0.0001, 0.01, 0.1, 1, 10]}

gs = GridSearchCV(classifier, parameters, cv=3, scoring = 'f1', verbose=10, n_jobs=-1, refit=True)

gs.fit(X_train,y_train)
# Out:
# Fitting 3 folds for each of 15 candidates, totalling 45 fits
# [CV 1/3; 1/15] START learning_rate=0.0001, n_estimators=50......................
# [CV 2/3; 1/15] START learning_rate=0.0001, n_estimators=50......................
# [CV 3/3; 1/15] START learning_rate=0.0001, n_estimators=50......................
# [CV 1/3; 2/15] START learning_rate=0.0001, n_estimators=100.....................
# [CV 2/3; 2/15] START learning_rate=0.0001, n_estimators=100.....................
# [CV 3/3; 2/15] START learning_rate=0.0001, n_estimators=100.....................
# [CV 1/3; 3/15] START learning_rate=0.0001, n_estimators=200.....................
# [CV 2/3; 3/15] START learning_rate=0.0001, n_estimators=200.....................
# [CV 3/3; 3/15] START learning_rate=0.0001, n_estimators=200.....................
# [CV 1/3; 4/15] START learning_rate=0.01, n_estimators=50........................
# [CV 2/3; 4/15] START learning_rate=0.01, n_estimators=50........................
# [CV 3/3; 4/15] START learning_rate=0.01, n_estimators=50........................
# [CV 2/3; 1/15] END learning_rate=0.0001, n_estimators=50;, score=0.571 total time=   0.2s
# [CV 1/3; 5/15] START learning_rate=0.01, n_estimators=100.......................
# [CV 3/3; 1/15] END learning_rate=0.0001, n_estimators=50;, score=0.490 total time=   0.2s
# [CV 2/3; 5/15] START learning_rate=0.01, n_estimators=100.......................
# [CV 2/3; 4/15] END learning_rate=0.01, n_estimators=50;, score=0.489 total time=   0.2s
# [CV 3/3; 5/15] START learning_rate=0.01, n_estimators=100.......................
# [CV 1/3; 1/15] END learning_rate=0.0001, n_estimators=50;, score=0.700 total time=   0.3s
# [CV 1/3; 6/15] START learning_rate=0.01, n_estimators=200.......................
# [CV 2/3; 2/15] END learning_rate=0.0001, n_estimators=100;, score=0.571 total time=   0.3s
# [CV 2/3; 6/15] START learning_rate=0.01, n_estimators=200.......................
# [CV 3/3; 2/15] END learning_rate=0.0001, n_estimators=100;, score=0.490 total time=   0.3s
# [CV 3/3; 6/15] START learning_rate=0.01, n_estimators=200.......................
# [CV 3/3; 4/15] END learning_rate=0.01, n_estimators=50;, score=0.490 total time=   0.4s
# [CV 1/3; 7/15] START learning_rate=0.1, n_estimators=50.........................
# [CV 3/3; 5/15] END learning_rate=0.01, n_estimators=100;, score=0.500 total time=   0.3s
# [CV 2/3; 7/15] START learning_rate=0.1, n_estimators=50.........................
# [CV 1/3; 5/15] END learning_rate=0.01, n_estimators=100;, score=0.543 total time=   0.4s
# [CV 3/3; 7/15] START learning_rate=0.1, n_estimators=50.........................[CV 1/3; 4/15] END learning_rate=0.01, n_estimators=50;, score=0.000 total time=   0.5s
#
# [CV 1/3; 8/15] START learning_rate=0.1, n_estimators=100........................
# [CV 2/3; 5/15] END learning_rate=0.01, n_estimators=100;, score=0.563 total time=   0.5s
# [CV 1/3; 3/15] END learning_rate=0.0001, n_estimators=200;, score=0.700 total time=   0.7s
# [CV 2/3; 8/15] START learning_rate=0.1, n_estimators=100........................
# [CV 3/3; 8/15] START learning_rate=0.1, n_estimators=100........................
# [CV 2/3; 3/15] END learning_rate=0.0001, n_estimators=200;, score=0.571 total time=   0.7s
# [CV 1/3; 9/15] START learning_rate=0.1, n_estimators=200........................
# [CV 1/3; 7/15] END learning_rate=0.1, n_estimators=50;, score=0.712 total time=   0.3s
# [CV 2/3; 7/15] END learning_rate=0.1, n_estimators=50;, score=0.569 total time=   0.2s
# [CV 2/3; 9/15] START learning_rate=0.1, n_estimators=200........................
# [CV 3/3; 9/15] START learning_rate=0.1, n_estimators=200........................
# [CV 3/3; 7/15] END learning_rate=0.1, n_estimators=50;, score=0.473 total time=   0.2s
# [CV 1/3; 10/15] START learning_rate=1, n_estimators=50..........................
# [CV 1/3; 2/15] END learning_rate=0.0001, n_estimators=100;, score=0.700 total time=   0.8s
# [CV 2/3; 10/15] START learning_rate=1, n_estimators=50..........................
# [CV 1/3; 10/15] END learning_rate=1, n_estimators=50;, score=0.646 total time=   0.2s
# [CV 3/3; 10/15] START learning_rate=1, n_estimators=50..........................
# [CV 3/3; 8/15] END learning_rate=0.1, n_estimators=100;, score=0.505 total time=   0.3s
# [CV 1/3; 11/15] START learning_rate=1, n_estimators=100.........................
# [CV 2/3; 10/15] END learning_rate=1, n_estimators=50;, score=0.643 total time=   0.2s
# [CV 2/3; 11/15] START learning_rate=1, n_estimators=100.........................
# [CV 2/3; 6/15] END learning_rate=0.01, n_estimators=200;, score=0.569 total time=   0.7s
# [CV 3/3; 11/15] START learning_rate=1, n_estimators=100.........................
# [CV 3/3; 6/15] END learning_rate=0.01, n_estimators=200;, score=0.500 total time=   0.7s
# [CV 1/3; 12/15] START learning_rate=1, n_estimators=200.........................
# [CV 2/3; 8/15] END learning_rate=0.1, n_estimators=100;, score=0.636 total time=   0.5s
# [CV 2/3; 12/15] START learning_rate=1, n_estimators=200.........................
# [CV 3/3; 10/15] END learning_rate=1, n_estimators=50;, score=0.519 total time=   0.2s
# [CV 3/3; 12/15] START learning_rate=1, n_estimators=200.........................
# [CV 1/3; 6/15] END learning_rate=0.01, n_estimators=200;, score=0.543 total time=   0.9s
# [CV 1/3; 13/15] START learning_rate=10, n_estimators=50.........................
# [CV 1/3; 11/15] END learning_rate=1, n_estimators=100;, score=0.672 total time=   0.3s
# [CV 2/3; 13/15] START learning_rate=10, n_estimators=50.........................
# [CV 1/3; 9/15] END learning_rate=0.1, n_estimators=200;, score=0.633 total time=   0.6s
# [CV 3/3; 13/15] START learning_rate=10, n_estimators=50.........................
# [CV 2/3; 11/15] END learning_rate=1, n_estimators=100;, score=0.631 total time=   0.3s
# [CV 1/3; 14/15] START learning_rate=10, n_estimators=100........................
# [CV 3/3; 11/15] END learning_rate=1, n_estimators=100;, score=0.527 total time=   0.4s
# [CV 2/3; 14/15] START learning_rate=10, n_estimators=100........................
# [CV 1/3; 8/15] END learning_rate=0.1, n_estimators=100;, score=0.655 total time=   0.8s
# [CV 2/3; 13/15] END learning_rate=10, n_estimators=50;, score=0.571 total time=   0.2s
# [CV 1/3; 15/15] START learning_rate=10, n_estimators=200........................
# [CV 3/3; 14/15] START learning_rate=10, n_estimators=100........................
# [CV 3/3; 13/15] END learning_rate=10, n_estimators=50;, score=0.490 total time=   0.2s
# [CV 2/3; 15/15] START learning_rate=10, n_estimators=200........................
# [CV 1/3; 13/15] END learning_rate=10, n_estimators=50;, score=0.700 total time=   0.3s
# [CV 3/3; 15/15] START learning_rate=10, n_estimators=200........................
# [CV 3/3; 3/15] END learning_rate=0.0001, n_estimators=200;, score=0.490 total time=   1.6s
# [CV 1/3; 12/15] END learning_rate=1, n_estimators=200;, score=0.667 total time=   0.6s
# [CV 1/3; 14/15] END learning_rate=10, n_estimators=100;, score=0.700 total time=   0.4s
# [CV 2/3; 14/15] END learning_rate=10, n_estimators=100;, score=0.571 total time=   0.4s
# [CV 3/3; 12/15] END learning_rate=1, n_estimators=200;, score=0.518 total time=   0.6s
# [CV 2/3; 12/15] END learning_rate=1, n_estimators=200;, score=0.637 total time=   0.7s
# [CV 3/3; 9/15] END learning_rate=0.1, n_estimators=200;, score=0.510 total time=   1.2s
# [CV 3/3; 14/15] END learning_rate=10, n_estimators=100;, score=0.490 total time=   0.5s
# [CV 2/3; 9/15] END learning_rate=0.1, n_estimators=200;, score=0.661 total time=   1.2s
# [CV 1/3; 15/15] END learning_rate=10, n_estimators=200;, score=0.700 total time=   0.5s
# [CV 3/3; 15/15] END learning_rate=10, n_estimators=200;, score=0.490 total time=   0.5s
# [CV 2/3; 15/15] END learning_rate=10, n_estimators=200;, score=0.571 total time=   0.6s
# GridSearchCV(cv=3, estimator=AdaBoostClassifier(), n_jobs=-1,
#              param_grid={'learning_rate': [0.0001, 0.01, 0.1, 1, 10],
#                          'n_estimators': [50, 100, 200]},
#              scoring='f1', verbose=10)

# %%
#summarize the results of your GRIDSEARCH
print('***GRIDSEARCH RESULTS***')

print("Best score: %f using %s" % (gs.best_score_, gs.best_params_))
means = gs.cv_results_['mean_test_score']
stds = gs.cv_results_['std_test_score']
params = gs.cv_results_['params']

for mean, stdev, param in zip(means, stds, params):
    print("%f (%f) with: %r" % (mean, stdev, param))
# Out:
# ***GRIDSEARCH RESULTS***
# Best score: 0.610012 using {'learning_rate': 1, 'n_estimators': 100}
# 0.587075 (0.086526) with: {'learning_rate': 0.0001, 'n_estimators': 50}
# 0.587075 (0.086526) with: {'learning_rate': 0.0001, 'n_estimators': 100}
# 0.587075 (0.086526) with: {'learning_rate': 0.0001, 'n_estimators': 200}
# 0.326386 (0.230790) with: {'learning_rate': 0.01, 'n_estimators': 50}
# 0.535528 (0.026369) with: {'learning_rate': 0.01, 'n_estimators': 100}
# 0.537369 (0.028348) with: {'learning_rate': 0.01, 'n_estimators': 200}
# 0.584537 (0.098115) with: {'learning_rate': 0.1, 'n_estimators': 50}
# 0.598548 (0.066434) with: {'learning_rate': 0.1, 'n_estimators': 100}
# 0.601363 (0.065409) with: {'learning_rate': 0.1, 'n_estimators': 200}
# 0.602510 (0.059406) with: {'learning_rate': 1, 'n_estimators': 50}
# 0.610012 (0.060909) with: {'learning_rate': 1, 'n_estimators': 100}
# 0.607231 (0.064334) with: {'learning_rate': 1, 'n_estimators': 200}
# 0.587075 (0.086526) with: {'learning_rate': 10, 'n_estimators': 50}
# 0.587075 (0.086526) with: {'learning_rate': 10, 'n_estimators': 100}
# 0.587075 (0.086526) with: {'learning_rate': 10, 'n_estimators': 200}

# %%
#TEST ON YOUR TEST SET
best_model = gs.best_estimator_
y_pred = best_model.predict(X_test)

# %%
# Plot confusion matrix
from sklearn.metrics import confusion_matrix
sns.heatmap(confusion_matrix(y_test, y_pred), annot=True, fmt='d', cmap="Reds", cbar=False)

plt.show()

# %%
from sklearn.metrics import classification_report

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.79      0.85      0.82       150
#            1       0.68      0.58      0.63        81
#
#     accuracy                           0.76       231
#    macro avg       0.74      0.72      0.72       231
# weighted avg       0.75      0.76      0.75       231

# %%
y_pred_train = best_model.predict(X_train)
print("f1_score_train: ", metrics.f1_score(y_train, y_pred_train))
print("f1_score_test: ", metrics.f1_score(y_test, y_pred))
# Out:
# f1_score_train:  0.7220630372492837
# f1_score_test:  0.6266666666666667

# %%
adaboost = AdaBoostClassifier(n_estimators=1000, learning_rate=0.01)

adaboost.fit(X_train,y_train)

y_probs = adaboost.predict_proba(X_test) #predict_proba gives the probabilities for the target (0 and 1 in your case)

fpr, tpr, thresholds=metrics.roc_curve(y_test,  y_probs[:,1])

import matplotlib.pyplot as plt
plt.plot(fpr, tpr, label='ROC')
plt.plot([0, 1], [0, 1], color='darkblue', linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend()
plt.show()

auc = metrics.roc_auc_score(y_test, y_probs[:,1])
print('AUC: %.2f' % auc)
# Out:
# AUC: 0.82

# %% [markdown]
# # Gradient boosting

# %%
## from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import GradientBoostingClassifier

classifier= GradientBoostingClassifier()
parameters = {'n_estimators' : [50, 100, 200],
    'learning_rate' : [0.0001, 0.01, 0.1, 1, 10]}

gs = GridSearchCV(classifier, parameters, cv=3, scoring = 'f1', verbose=10, n_jobs=-1, refit=True)

gs.fit(X_train,y_train)
# Out:
# Fitting 3 folds for each of 15 candidates, totalling 45 fits
# [CV 1/3; 1/15] START learning_rate=0.0001, n_estimators=50......................
# [CV 2/3; 1/15] START learning_rate=0.0001, n_estimators=50......................
# [CV 3/3; 1/15] START learning_rate=0.0001, n_estimators=50......................
# [CV 1/3; 2/15] START learning_rate=0.0001, n_estimators=100.....................
# [CV 2/3; 2/15] START learning_rate=0.0001, n_estimators=100.....................
# [CV 3/3; 2/15] START learning_rate=0.0001, n_estimators=100.....................
# [CV 1/3; 3/15] START learning_rate=0.0001, n_estimators=200.....................
# [CV 2/3; 3/15] START learning_rate=0.0001, n_estimators=200.....................
# [CV 3/3; 3/15] START learning_rate=0.0001, n_estimators=200.....................
# [CV 1/3; 4/15] START learning_rate=0.01, n_estimators=50........................
# [CV 3/3; 4/15] START learning_rate=0.01, n_estimators=50........................
# [CV 2/3; 4/15] START learning_rate=0.01, n_estimators=50........................
# [CV 1/3; 1/15] END learning_rate=0.0001, n_estimators=50;, score=0.000 total time=   0.1s
# [CV 1/3; 5/15] START learning_rate=0.01, n_estimators=100.......................
# [CV 3/3; 1/15] END learning_rate=0.0001, n_estimators=50;, score=0.000 total time=   0.2s
# [CV 2/3; 5/15] START learning_rate=0.01, n_estimators=100.......................
# [CV 2/3; 1/15] END learning_rate=0.0001, n_estimators=50;, score=0.000 total time=   0.2s
# [CV 3/3; 5/15] START learning_rate=0.01, n_estimators=100.......................
# [CV 2/3; 4/15] END learning_rate=0.01, n_estimators=50;, score=0.444 total time=   0.3s
# [CV 1/3; 6/15] START learning_rate=0.01, n_estimators=200.......................
# [CV 1/3; 2/15] END learning_rate=0.0001, n_estimators=100;, score=0.000 total time=   0.3s
# [CV 2/3; 6/15] START learning_rate=0.01, n_estimators=200.......................
# [CV 1/3; 4/15] END learning_rate=0.01, n_estimators=50;, score=0.359 total time=   0.4s
# [CV 3/3; 6/15] START learning_rate=0.01, n_estimators=200.......................
# [CV 3/3; 4/15] END learning_rate=0.01, n_estimators=50;, score=0.430 total time=   0.4s
# [CV 1/3; 7/15] START learning_rate=0.1, n_estimators=50.........................
# [CV 3/3; 2/15] END learning_rate=0.0001, n_estimators=100;, score=0.000 total time=   0.4s
# [CV 2/3; 7/15] START learning_rate=0.1, n_estimators=50.........................
# [CV 1/3; 5/15] END learning_rate=0.01, n_estimators=100;, score=0.623 total time=   0.3s
# [CV 3/3; 7/15] START learning_rate=0.1, n_estimators=50.........................
# [CV 2/3; 2/15] END learning_rate=0.0001, n_estimators=100;, score=0.000 total time=   0.5s
# [CV 2/3; 5/15] END learning_rate=0.01, n_estimators=100;, score=0.545 total time=   0.3s
# [CV 1/3; 8/15] START learning_rate=0.1, n_estimators=100........................
# [CV 2/3; 8/15] START learning_rate=0.1, n_estimators=100........................
# [CV 3/3; 3/15] END learning_rate=0.0001, n_estimators=200;, score=0.000 total time=   0.5s
# [CV 3/3; 8/15] START learning_rate=0.1, n_estimators=100........................
# [CV 3/3; 7/15] END learning_rate=0.1, n_estimators=50;, score=0.490 total time=   0.1s
# [CV 1/3; 9/15] START learning_rate=0.1, n_estimators=200........................
# [CV 3/3; 5/15] END learning_rate=0.01, n_estimators=100;, score=0.469 total time=   0.4s
# [CV 2/3; 9/15] START learning_rate=0.1, n_estimators=200........................
# [CV 1/3; 3/15] END learning_rate=0.0001, n_estimators=200;, score=0.000 total time=   0.7s
# [CV 3/3; 9/15] START learning_rate=0.1, n_estimators=200........................
# [CV 2/3; 7/15] END learning_rate=0.1, n_estimators=50;, score=0.602 total time=   0.3s
# [CV 1/3; 10/15] START learning_rate=1, n_estimators=50..........................
# [CV 1/3; 7/15] END learning_rate=0.1, n_estimators=50;, score=0.598 total time=   0.4s
# [CV 2/3; 10/15] START learning_rate=1, n_estimators=50..........................
# [CV 3/3; 8/15] END learning_rate=0.1, n_estimators=100;, score=0.509 total time=   0.3s
# [CV 3/3; 10/15] START learning_rate=1, n_estimators=50..........................
# [CV 2/3; 10/15] END learning_rate=1, n_estimators=50;, score=0.603 total time=   0.2s
# [CV 1/3; 11/15] START learning_rate=1, n_estimators=100.........................
# [CV 1/3; 10/15] END learning_rate=1, n_estimators=50;, score=0.603 total time=   0.2s
# [CV 2/3; 11/15] START learning_rate=1, n_estimators=100.........................
# [CV 3/3; 10/15] END learning_rate=1, n_estimators=50;, score=0.518 total time=   0.1s
# [CV 2/3; 3/15] END learning_rate=0.0001, n_estimators=200;, score=0.000 total time=   0.9s
# [CV 3/3; 11/15] START learning_rate=1, n_estimators=100.........................
# [CV 1/3; 12/15] START learning_rate=1, n_estimators=200.........................
# [CV 2/3; 6/15] END learning_rate=0.01, n_estimators=200;, score=0.607 total time=   0.6s
# [CV 2/3; 12/15] START learning_rate=1, n_estimators=200.........................
# [CV 1/3; 6/15] END learning_rate=0.01, n_estimators=200;, score=0.602 total time=   0.7s
# [CV 3/3; 12/15] START learning_rate=1, n_estimators=200.........................
# [CV 2/3; 8/15] END learning_rate=0.1, n_estimators=100;, score=0.603 total time=   0.5s
# [CV 1/3; 13/15] START learning_rate=10, n_estimators=50.........................
# [CV 3/3; 6/15] END learning_rate=0.01, n_estimators=200;, score=0.484 total time=   0.7s
# [CV 2/3; 13/15] START learning_rate=10, n_estimators=50.........................
# [CV 1/3; 8/15] END learning_rate=0.1, n_estimators=100;, score=0.614 total time=   0.6s
# [CV 3/3; 13/15] START learning_rate=10, n_estimators=50.........................
# [CV 1/3; 13/15] END learning_rate=10, n_estimators=50;, score=0.502 total time=   0.1s
# [CV 1/3; 14/15] START learning_rate=10, n_estimators=100........................
# [CV 1/3; 11/15] END learning_rate=1, n_estimators=100;, score=0.606 total time=   0.3s
# [CV 2/3; 14/15] START learning_rate=10, n_estimators=100........................
# [CV 2/3; 11/15] END learning_rate=1, n_estimators=100;, score=0.579 total time=   0.3s
# [CV 3/3; 14/15] START learning_rate=10, n_estimators=100........................
# [CV 2/3; 13/15] END learning_rate=10, n_estimators=50;, score=0.515 total time=   0.1s
# [CV 1/3; 15/15] START learning_rate=10, n_estimators=200........................
# [CV 3/3; 11/15] END learning_rate=1, n_estimators=100;, score=0.522 total time=   0.3s
# [CV 2/3; 15/15] START learning_rate=10, n_estimators=200........................
# [CV 1/3; 9/15] END learning_rate=0.1, n_estimators=200;, score=0.646 total time=   0.7s
# [CV 3/3; 15/15] START learning_rate=10, n_estimators=200........................
# [CV 3/3; 13/15] END learning_rate=10, n_estimators=50;, score=0.381 total time=   0.2s
# [CV 2/3; 9/15] END learning_rate=0.1, n_estimators=200;, score=0.571 total time=   0.7s
# [CV 2/3; 14/15] END learning_rate=10, n_estimators=100;, score=0.515 total time=   0.3s
# [CV 1/3; 12/15] END learning_rate=1, n_estimators=200;, score=0.569 total time=   0.5s
# [CV 3/3; 9/15] END learning_rate=0.1, n_estimators=200;, score=0.527 total time=   0.7s
# [CV 2/3; 12/15] END learning_rate=1, n_estimators=200;, score=0.562 total time=   0.5s
# [CV 3/3; 14/15] END learning_rate=10, n_estimators=100;, score=0.381 total time=   0.3s
# [CV 1/3; 14/15] END learning_rate=10, n_estimators=100;, score=0.507 total time=   0.3s
# [CV 3/3; 12/15] END learning_rate=1, n_estimators=200;, score=0.538 total time=   0.7s
# [CV 1/3; 15/15] END learning_rate=10, n_estimators=200;, score=0.507 total time=   0.5s
# [CV 3/3; 15/15] END learning_rate=10, n_estimators=200;, score=0.381 total time=   0.4s
# [CV 2/3; 15/15] END learning_rate=10, n_estimators=200;, score=0.515 total time=   0.5s
# GridSearchCV(cv=3, estimator=GradientBoostingClassifier(), n_jobs=-1,
#              param_grid={'learning_rate': [0.0001, 0.01, 0.1, 1, 10],
#                          'n_estimators': [50, 100, 200]},
#              scoring='f1', verbose=10)

# %%
#summarize the results of your GRIDSEARCH
print('***GRIDSEARCH RESULTS***')

print("Best score: %f using %s" % (gs.best_score_, gs.best_params_))
means = gs.cv_results_['mean_test_score']
stds = gs.cv_results_['std_test_score']
params = gs.cv_results_['params']

for mean, stdev, param in zip(means, stds, params):
    print("%f (%f) with: %r" % (mean, stdev, param))
# Out:
# ***GRIDSEARCH RESULTS***
# Best score: 0.581618 using {'learning_rate': 0.1, 'n_estimators': 200}
# 0.000000 (0.000000) with: {'learning_rate': 0.0001, 'n_estimators': 50}
# 0.000000 (0.000000) with: {'learning_rate': 0.0001, 'n_estimators': 100}
# 0.000000 (0.000000) with: {'learning_rate': 0.0001, 'n_estimators': 200}
# 0.411175 (0.037373) with: {'learning_rate': 0.01, 'n_estimators': 50}
# 0.545828 (0.062566) with: {'learning_rate': 0.01, 'n_estimators': 100}
# 0.564326 (0.056695) with: {'learning_rate': 0.01, 'n_estimators': 200}
# 0.563464 (0.051826) with: {'learning_rate': 0.1, 'n_estimators': 50}
# 0.575685 (0.047051) with: {'learning_rate': 0.1, 'n_estimators': 100}
# 0.581618 (0.049065) with: {'learning_rate': 0.1, 'n_estimators': 200}
# 0.574827 (0.040284) with: {'learning_rate': 1, 'n_estimators': 50}
# 0.568771 (0.035107) with: {'learning_rate': 1, 'n_estimators': 100}
# 0.556343 (0.013431) with: {'learning_rate': 1, 'n_estimators': 200}
# 0.465893 (0.060272) with: {'learning_rate': 10, 'n_estimators': 50}
# 0.467381 (0.061198) with: {'learning_rate': 10, 'n_estimators': 100}
# 0.467381 (0.061198) with: {'learning_rate': 10, 'n_estimators': 200}

# %%
#TEST ON YOUR TEST SET
best_model = gs.best_estimator_
y_pred = best_model.predict(X_test)

# %%
# Plot confusion matrix
from sklearn.metrics import confusion_matrix
sns.heatmap(confusion_matrix(y_test, y_pred), annot=True, fmt='d', cmap="Reds", cbar=False);

# %%
from sklearn.metrics import classification_report

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.80      0.83      0.81       150
#            1       0.66      0.62      0.64        81
#
#     accuracy                           0.75       231
#    macro avg       0.73      0.72      0.73       231
# weighted avg       0.75      0.75      0.75       231

# %%
y_pred_train = best_model.predict(X_train)
print("f1_score_train: ", metrics.f1_score(y_train, y_pred_train))
print("f1_score_test: ", metrics.f1_score(y_test, y_pred))
# Out:
# f1_score_train:  0.9838709677419355
# f1_score_test:  0.6369426751592356

# %% [markdown]
# ### One final word: remember, Bagging and Boosting methods are not restricted to trees for weak learners!
